# %%
import ROOT
from fitHelper import Plotter, draw_overlaid_stacks
# Out:
# OBJ: TStyle	ildStyle	ILD Style : 0 at: 0x8d30b10
# OBJ: TStyle	ildStyle	ILD Style : 0 at: 0x8d26850

# %%
def get_fit_results(fitres_dir: str, run_conf_names: list[str], lumi_list, oo_names):
    fit_results = {}
    for oo_name in oo_names:
        fs = {}
        for name in run_conf_names:
            for run_ab in lumi_list:
                run_name = f"{name}_{run_ab}ab"
                with ROOT.TFile.Open(f"{fitres_dir}/{oo_name}_{run_name}_fitres.root") as in_file:
                    fit_res = in_file.Get("fit_result_nominal")
                fs[run_name] = fit_res
        fit_results[oo_name] = fs
    return fit_results

# %%
run_conf_names = [
    "new_share_high_ppol",
    "old_share_high_ppol",
    "new_share_low_ppol",
    "old_share_low_ppol",
    "new_share_no_ppol",
    "old_share_no_ppol",
    "equal_share_high_ppol",
    "equal_share_low_ppol",
    "no_pol"
]
lumi_list = [2, 3, 10.8]

# %%
oo_names = [
    "mlvec_reco",
    "reco",
    "mlvec_reco_jm",
    "reco_jm",
    "mlvec_clean_reco",
    "clean_reco",
    "mlvec_clean_brems_reco",
    "clean_brems_reco",
    # "kinfit_clean_reco",
    "mlvec_clean_reco_jm",
    "clean_reco_jm",
    "clean_brems_reco_jm",
    "mlvec_clean_brems_reco_jm",
    # "kinfit_clean_reco_jm",
    "mlvec_cheat_clean_reco",
    "cheat_clean_reco",
    "mlvec_cheat_clean_reco_jm",
    "cheat_clean_reco_jm",
    "mc",
    "nomb_mc",
    "nomb_mc_rlep",
    "nomb_mc_rlep_gamma",
    "nomb_mc_rlep_brems",
    "nomb_mc_rlep_cheated_brems",
    "nurec_nomb_mc",
    "nurec_nomb_mc_rlep",
    "nurec_nomb_mc_rlep_gamma",
    "nurec_nomb_mc_rlep_brems",
    "nurec_nomb_mc_rlep_cheated_brems",
    "nurec_post94_mc",
    "av_mc",
    "av_nomb_mc",
    "av_nomb_mc_rlep",
    "av_nomb_mc_rlep_gamma",
    "av_nomb_mc_rlep_brems",
    "av_nomb_mc_rlep_cheated_brems",
    "av_nurec_nomb_mc",
    "av_nurec_nomb_mc_rlep",
    "av_nurec_nomb_mc_rlep_gamma",
    "av_nurec_nomb_mc_rlep_brems",
    "av_nurec_nomb_mc_rlep_cheated_brems",
    "av_nurec_post94_mc",
    "av_nurec_nomb_mc_cc10",
    "mlvec_clean_brems_reco_cc10",
    "mlvec_clean_brems_reco_san",
]

reduced_oo_names = [
    "mlvec_clean_brems_reco",
    "mlvec_clean_brems_reco_jm",
    "mlvec_clean_brems_reco_cc10",
    "av_nurec_nomb_mc",
    "nurec_nomb_mc",
    "av_nurec_nomb_mc_cc10",
]

# %%
prefix = "data/new_fit_results"
fit_results = {
    "free_pol": get_fit_results(f"{prefix}/free_pol/", run_conf_names, lumi_list, reduced_oo_names),
    "constrained_pol": get_fit_results(f"{prefix}/pol_constrained_2.5em3/", run_conf_names, lumi_list, oo_names),
    "constrained_pol_fixed_mW": get_fit_results(f"{prefix}/pol_constrained_2.5em3_fixed_mW/", run_conf_names, lumi_list, reduced_oo_names),
    "constrained_pol_constrained_mW": get_fit_results(f"{prefix}/pol_constrained_2.5em3_mW_constrained_2MeV/", run_conf_names, lumi_list, reduced_oo_names),
    "fixed_pol": get_fit_results(f"{prefix}/fixed_pol/", run_conf_names, lumi_list, reduced_oo_names),
    "fixed_mW": get_fit_results(f"{prefix}/fixed_mW/", run_conf_names, lumi_list, reduced_oo_names),
}

# %%
legend_name_dict_oo = {
    "reco": "Reco, E-scheme",
    "mlvec_reco": "Reco, P-scheme",
    "clean_reco": "Reco, E-scheme, BIB-removal",
    "mlvec_clean_reco": "Reco, P-scheme, BIB-removal",
    "clean_brems_reco": "Reco, E-scheme, BIB-removal + brems",
    "mlvec_clean_brems_reco": "Reco, P-scheme, BIB-removal + brems",
    "cheat_clean_reco": "Reco, E-scheme, cheat BIB-removal",
    "mlvec_cheat_clean_reco": "Reco, P-scheme, cheat BIB-removal",
    "mlvec_clean_brems_reco_jm": "Best reco + perfect jet-charge",
    "mlvec_clean_brems_reco_cc10": "Best reco, WW only",
    "av_nurec_nomb_mc": "MC",
    "av_mc": "MC + cheat #sqrt{s}",
    "nurec_nomb_mc": "MC + perfect jet-charge",
    "av_nurec_nomb_mc_cc10": "MC, WW only",
    "av_nurec_nomb_mc_rlep": "MC + Reco lep",
    "av_nurec_nomb_mc_rlep_gamma": "MC + Reco lep, iso-#gamma brems",
    "av_nurec_nomb_mc_rlep_brems": "MC + Reco lep, window brems",
    "av_nurec_nomb_mc_rlep_cheated_brems": "MC + Reco lep, cheated brems",
}
name_dict_run_confs = {
    "no_pol": "P(0,0)",
    "new_share_high_ppol": "P(#pm0.8,#pm0.6), (5%,45%,45%,5%)",
    "old_share_high_ppol": "P(#pm0.8,#pm0.6), (5%,67.5%,22.5%,5%)",
    "new_share_low_ppol": "P(#pm0.8,#pm0.3), (5%,45%,45%,5%)",
    "old_share_low_ppol": "P(#pm0.8,#pm0.3), (5%,67.5%,22.5%,5%)",
    "new_share_no_ppol": "P(#pm0.8,0), (50%,50%)",
    "old_share_no_ppol": "P(#pm0.8,0), (72.5%,27.5%)",
    "equal_share_high_ppol": "P(#pm0.8,#pm0.6), (25%,25%,25%,25%)",
    "equal_share_low_ppol": "P(#pm0.8,#pm0.3), (25%,25%,25%,25%)",
}
legend_name_dict_oo |= {f"{name}_{run_ab}ab": f"{text}, {run_ab} ab^{{-1}}" for run_ab in lumi_list for name, text in name_dict_run_confs.items()}

x_axis_label_dict = {
    "g1z": "g_{1}^{Z}",
    "ka": "#kappa_{#gamma}",
    "la": "#lambda_{#gamma}",
    "mW": "m_{W}",
    "e_pol_L": "P_{e^{-}}^{-}",
    "e_pol_R": "P_{e^{-}}^{+}",
    "e_pol_0": "P_{e^{-}}^{0}",
    "p_pol_L": "P_{e^{+}}^{-}",
    "p_pol_R": "P_{e^{+}}^{+}",
    "p_pol_0": "P_{e^{+}}^{0}",
}

# %%
plotters = {key: Plotter() for key in fit_results}
plot_dir = "plots/new_fit_results_bars"

# %%
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_mc", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "mc",
    "av_mc",
], parameter_names=[
    "g1z",
    "ka",
    "la",
], legend_name_dict=legend_name_dict_oo, x_label_dict=x_axis_label_dict)
# Out:
# <div id="root_plot_1771778975808" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778975808() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25569,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778975808', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778975808();
# </script>

# %%
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_mc_ISR", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "av_mc",
    "av_nurec_nomb_mc"
], parameter_names=[
    "g1z",
    "ka",
    "la",
    "mW"
], legend_name_dict=legend_name_dict_oo, x_label_dict=x_axis_label_dict, plot_dir=plot_dir)
# Out:
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_mc_ISR_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_mc_ISR.pdf has been created
# <div id="root_plot_1771778976004" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778976004() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(26021,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778976004', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778976004();
# </script>

# %%
# mlvec and BIB-removal
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_mlvec_or_not", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "mlvec_reco",
    "reco",
    "mlvec_clean_reco",
    "clean_reco",
    "mlvec_cheat_clean_reco",
    "cheat_clean_reco",
    # "mlvec_clean_brems_reco",
    # "clean_brems_reco",
], parameter_names=[
    "g1z",
    "ka",
    "la",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.14, 0.68, 0.42), plot_dir=plot_dir, x_label_dict=x_axis_label_dict)
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_mW_mlvec_or_not", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "mlvec_reco",
    "reco",
    "mlvec_clean_reco",
    "clean_reco",
    "mlvec_cheat_clean_reco",
    "cheat_clean_reco",
    # "mlvec_clean_brems_reco",
    # "clean_brems_reco",
], parameter_names=[
    "mW",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.14, 0.68, 0.42), plot_dir=plot_dir, x_label_dict=x_axis_label_dict, unit="GeV")
# Out:
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_mlvec_or_not_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_mlvec_or_not.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_mW_mlvec_or_not_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_mW_mlvec_or_not.pdf has been created
# <div id="root_plot_1771778976413" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778976413() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(35964,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778976413', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778976413();
# </script>
# <div id="root_plot_1771778976416" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778976416() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(34279,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778976416', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778976416();
# </script>

# %%
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_brems_mc", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "av_nurec_nomb_mc_rlep",
    "av_nurec_nomb_mc_rlep_gamma",
    "av_nurec_nomb_mc_rlep_brems",
    "av_nurec_nomb_mc_rlep_cheated_brems",
    "av_nurec_nomb_mc",
], parameter_names=[
    "g1z",
    "ka",
    "la",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.14, 0.68, 0.42), plot_dir=plot_dir, x_label_dict=x_axis_label_dict)
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_mW_brems_mc", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "av_nurec_nomb_mc_rlep",
    "av_nurec_nomb_mc_rlep_gamma",
    "av_nurec_nomb_mc_rlep_brems",
    "av_nurec_nomb_mc_rlep_cheated_brems",
    "av_nurec_nomb_mc",
], parameter_names=[
    "mW",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.14, 0.68, 0.42), plot_dir=plot_dir, x_label_dict=x_axis_label_dict, unit="GeV")
# Out:
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_brems_mc_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_brems_mc.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_mW_brems_mc_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_mW_brems_mc.pdf has been created
# <div id="root_plot_1771778976810" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778976810() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(33336,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778976810', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778976810();
# </script>
# <div id="root_plot_1771778976812" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778976812() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(31907,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778976812', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778976812();
# </script>

# %%
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_brems_reco", "no_pol_3ab", fit_results["constrained_pol"]  , oo_names=[
    "mlvec_clean_reco",
    # "clean_reco",
    "mlvec_clean_brems_reco",
    # "clean_brems_reco",
], parameter_names=[
    "g1z",
    "ka",
    "la",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.14, 0.68, 0.42), plot_dir=plot_dir, x_label_dict=x_axis_label_dict)
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_mW_brems_reco", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "mlvec_clean_reco",
    # "clean_reco",
    "mlvec_clean_brems_reco",
    # "clean_brems_reco",
], parameter_names=[
    "mW",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.14, 0.68, 0.42), plot_dir=plot_dir, x_label_dict=x_axis_label_dict, unit="GeV")
# Out:
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_brems_reco_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_brems_reco.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_mW_brems_reco_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_mW_brems_reco.pdf has been created
# <div id="root_plot_1771778977314" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778977314() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25568,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778977314', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778977314();
# </script>
# <div id="root_plot_1771778977319" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778977319() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(24890,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778977319', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778977319();
# </script>

# %%
# final reco to mc comparison
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_mW_reco_mc", "no_pol_3ab", fit_results["constrained_pol"]  , oo_names=[
    "mlvec_clean_brems_reco",
    "av_nurec_nomb_mc",
], parameter_names=[
    "g1z",
    "ka",
    "la",
    "mW",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.60, 0.68, 0.87), plot_dir=plot_dir, x_label_dict=x_axis_label_dict)
# Out:
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_mW_reco_mc_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_mW_reco_mc.pdf has been created
# <div id="root_plot_1771778977546" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778977546() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25982,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778977546', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778977546();
# </script>

# %%
local_dict = {
    "mlvec_clean_brems_reco": "Best reco",
    "mlvec_clean_brems_reco_jm": "Best reco + perfect jet-charge",
    "av_nurec_nomb_mc": "MC",
    "nurec_nomb_mc": "MC + perfect jet-charge",
    "no_pol_3ab": "P(0,0), 3 ab^{-1}",
}
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_jet_charge", "no_pol_3ab", fit_results["constrained_pol"]  , oo_names=[
    "mlvec_clean_brems_reco",
    "mlvec_clean_brems_reco_jm",
    "av_nurec_nomb_mc",
    "nurec_nomb_mc",
], parameter_names=[
    "g1z",
    "ka",
    "la",
], legend_name_dict=local_dict, legend_pars=(0.17, 0.14, 0.68, 0.41), plot_dir=plot_dir, x_label_dict=x_axis_label_dict)
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_mW_jet_charge", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "mlvec_clean_brems_reco",
    "mlvec_clean_brems_reco_jm",
    "av_nurec_nomb_mc",
    "nurec_nomb_mc",
], parameter_names=[
    "mW",
], legend_name_dict=local_dict, legend_pars=(0.17, 0.14, 0.68, 0.41), plot_dir=plot_dir, x_label_dict=x_axis_label_dict, unit="GeV")
# plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_pol_jet_charge", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
plotters["free_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_pol_jet_charge", "no_pol_3ab", fit_results["free_pol"], oo_names=[
    "mlvec_clean_brems_reco",
    "mlvec_clean_brems_reco_jm",
    "av_nurec_nomb_mc",
    "nurec_nomb_mc",
], parameter_names=[
    "e_pol_0",
    "p_pol_0",
], legend_name_dict=local_dict, legend_pars=(0.17, 0.14, 0.68, 0.41), plot_dir=plot_dir, x_label_dict=x_axis_label_dict, unit="GeV")
# plotters["constrained_pol"].draw_plots_oo_names_per_run_name("new_share_low_ppol_3ab_pol_jet_charge", "new_share_low_ppol_3ab", fit_results["constrained_pol"], oo_names=[
plotters["free_pol"].draw_plots_oo_names_per_run_name("new_share_low_ppol_3ab_pol_jet_charge", "new_share_low_ppol_3ab", fit_results["free_pol"], oo_names=[
    "mlvec_clean_brems_reco",
    "mlvec_clean_brems_reco_jm",
    "av_nurec_nomb_mc",
    "nurec_nomb_mc",
], parameter_names=[
    "e_pol_L",
    "e_pol_R",
    "p_pol_L",
    "p_pol_R",
], legend_name_dict=local_dict, legend_pars=(0.17, 0.14, 0.68, 0.41), plot_dir=plot_dir, x_label_dict=x_axis_label_dict, unit="GeV")
# Out:
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_jet_charge_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_jet_charge.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_mW_jet_charge_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_mW_jet_charge.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_pol_jet_charge_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_pol_jet_charge.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/new_share_low_ppol_3ab_pol_jet_charge_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/new_share_low_ppol_3ab_pol_jet_charge.pdf has been created
# <div id="root_plot_1771778978056" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978056() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(30723,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978056', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978056();
# </script>
# <div id="root_plot_1771778978061" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978061() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(29542,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978061', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978061();
# </script>
# <div id="root_plot_1771778978067" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978067() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(30152,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978067', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978067();
# </script>
# <div id="root_plot_1771778978071" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978071() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(31569,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978071', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978071();
# </script>

# %%
for k in ["free_pol", "constrained_pol", "fixed_pol"]:
    fit_res = fit_results[k]
    p = plotters[k]
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_big_comp_TGC", "mlvec_clean_brems_reco", fit_res, parameter_names=["g1z", "ka", "la", ], legend_pars=(0.7,0.55,1.,1.), legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_high_ppol_3ab",
                                      "old_share_high_ppol_3ab",
                                      "new_share_low_ppol_3ab",
                                      "old_share_low_ppol_3ab",
                                      "new_share_no_ppol_3ab",
                                      "old_share_no_ppol_3ab",
                                      "equal_share_high_ppol_3ab",
                                      "equal_share_low_ppol_3ab",
                                      "no_pol_3ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_big_comp_mW", "mlvec_clean_brems_reco", fit_res, parameter_names=["mW", ], legend_pars=(0.7, 0., 1., 0.45),
                                  legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_high_ppol_3ab",
                                      "old_share_high_ppol_3ab",
                                      "new_share_low_ppol_3ab",
                                      "old_share_low_ppol_3ab",
                                      "new_share_no_ppol_3ab",
                                      "old_share_no_ppol_3ab",
                                      "equal_share_high_ppol_3ab",
                                      "equal_share_low_ppol_3ab",
                                      "no_pol_3ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_big_comp_pols", "mlvec_clean_brems_reco", fit_res, parameter_names=["e_pol_L", "e_pol_R", "e_pol_0", "p_pol_L", "p_pol_R", "p_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                            "new_share_high_ppol_3ab",
                                            "old_share_high_ppol_3ab",
                                            "new_share_low_ppol_3ab",
                                            "old_share_low_ppol_3ab",
                                            "new_share_no_ppol_3ab",
                                            "old_share_no_ppol_3ab",
                                            "equal_share_high_ppol_3ab",
                                            "equal_share_low_ppol_3ab",
                                            "no_pol_3ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)

    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_big_comp_epols", "mlvec_clean_brems_reco", fit_res, parameter_names=["e_pol_L", "e_pol_R", "e_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                            "new_share_high_ppol_3ab",
                                            "old_share_high_ppol_3ab",
                                            "new_share_low_ppol_3ab",
                                            "old_share_low_ppol_3ab",
                                            "new_share_no_ppol_3ab",
                                            "old_share_no_ppol_3ab",
                                            "equal_share_high_ppol_3ab",
                                            "equal_share_low_ppol_3ab",
                                            "no_pol_3ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)

    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_big_comp_ppols", "mlvec_clean_brems_reco", fit_res, parameter_names=["p_pol_L", "p_pol_R", "p_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                            "new_share_high_ppol_3ab",
                                            "old_share_high_ppol_3ab",
                                            "new_share_low_ppol_3ab",
                                            "old_share_low_ppol_3ab",
                                            "new_share_no_ppol_3ab",
                                            "old_share_no_ppol_3ab",
                                            "equal_share_high_ppol_3ab",
                                            "equal_share_low_ppol_3ab",
                                            "no_pol_3ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
# Out:
# <div id="root_plot_1771778978205" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978205() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43941,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978205', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978205();
# </script>
# <div id="root_plot_1771778978209" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978209() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(41501,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978209', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978209();
# </script>
# <div id="root_plot_1771778978214" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978214() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(47259,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978214', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978214();
# </script>
# <div id="root_plot_1771778978219" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978219() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43580,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978219', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978219();
# </script>
# <div id="root_plot_1771778978223" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978223() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43517,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978223', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978223();
# </script>
# <div id="root_plot_1771778978228" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978228() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43955,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978228', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978228();
# </script>
# <div id="root_plot_1771778978233" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978233() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(41500,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978233', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978233();
# </script>
# <div id="root_plot_1771778978237" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978237() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(47271,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978237', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978237();
# </script>
# <div id="root_plot_1771778978242" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978242() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43595,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978242', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978242();
# </script>
# <div id="root_plot_1771778978246" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978246() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43523,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978246', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978246();
# </script>
# <div id="root_plot_1771778978250" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978250() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43952,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978250', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978250();
# </script>
# <div id="root_plot_1771778978255" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978255() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(41504,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978255', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978255();
# </script>
# <div id="root_plot_1771778978259" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978259() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(45339,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978259', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978259();
# </script>
# <div id="root_plot_1771778978264" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978264() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(42598,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978264', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978264();
# </script>
# <div id="root_plot_1771778978268" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778978268() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(42598,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778978268', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778978268();
# </script>

# %%
more_canvs = []
extra_legend_text = ["Free pol.", "Constrained pol.", "Fixed pol."]
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_big_comp_TGC", "mlvec_clean_brems_reco_big_comp_TGC", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, y_max=1.95e-3, legend_columns=2, legend_pos=(0.16, 0.71, 0.94, 0.91), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_big_comp_mW", "mlvec_clean_brems_reco_big_comp_mW", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_columns=2, legend_pos=(0.16, 0.15, 0.94, 0.40), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_big_comp_pols", "mlvec_clean_brems_reco_big_comp_pols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_big_comp_epols", "mlvec_clean_brems_reco_big_comp_epols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.46, 0.38, 0.93, 0.89), y_max=1.8e-2, extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_big_comp_ppols", "mlvec_clean_brems_reco_big_comp_ppols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, y_max=1.8e-2, extra_legend_texts=extra_legend_text))
# Out:
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_big_comp_TGC_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_big_comp_TGC_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_big_comp_mW_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_big_comp_mW_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_big_comp_pols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_big_comp_pols_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_big_comp_epols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_big_comp_epols_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_big_comp_ppols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_big_comp_ppols_overlaid_stacks.pdf has been created
# <div id="root_plot_1771778979387" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979387() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(90845,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979387', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979387();
# </script>
# <div id="root_plot_1771778979396" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979396() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(83520,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979396', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979396();
# </script>
# <div id="root_plot_1771778979401" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979401() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(74308,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979401', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979401();
# </script>
# <div id="root_plot_1771778979403" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979403() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(66914,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979403', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979403();
# </script>
# <div id="root_plot_1771778979406" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979406() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(66774,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979406', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979406();
# </script>

# %%
for k in ["free_pol", "constrained_pol", "fixed_pol"]:
    fit_res = fit_results[k]
    p = plotters[k]
    p.draw_plots_runs_per_oo_name("av_nurec_nomb_mc_big_comp_TGC", "av_nurec_nomb_mc", fit_res, parameter_names=["g1z", "ka", "la", ], legend_pars=(0.7,0.55,1.,1.), legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_high_ppol_3ab",
                                      "old_share_high_ppol_3ab",
                                      "new_share_low_ppol_3ab",
                                      "old_share_low_ppol_3ab",
                                      "new_share_no_ppol_3ab",
                                      "old_share_no_ppol_3ab",
                                      "equal_share_high_ppol_3ab",
                                      "equal_share_low_ppol_3ab",
                                      "no_pol_3ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("av_nurec_nomb_mc_big_comp_mW", "av_nurec_nomb_mc", fit_res, parameter_names=["mW", ], legend_pars=(0.7, 0., 1., 0.45),
                                  legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_high_ppol_3ab",
                                      "old_share_high_ppol_3ab",
                                      "new_share_low_ppol_3ab",
                                      "old_share_low_ppol_3ab",
                                      "new_share_no_ppol_3ab",
                                      "old_share_no_ppol_3ab",
                                      "equal_share_high_ppol_3ab",
                                      "equal_share_low_ppol_3ab",
                                      "no_pol_3ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("av_nurec_nomb_mc_big_comp_pols", "av_nurec_nomb_mc", fit_res, parameter_names=["e_pol_L", "e_pol_R", "e_pol_0", "p_pol_L", "p_pol_R", "p_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                            "new_share_high_ppol_3ab",
                                            "old_share_high_ppol_3ab",
                                            "new_share_low_ppol_3ab",
                                            "old_share_low_ppol_3ab",
                                            "new_share_no_ppol_3ab",
                                            "old_share_no_ppol_3ab",
                                            "equal_share_high_ppol_3ab",
                                            "equal_share_low_ppol_3ab",
                                            "no_pol_3ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("av_nurec_nomb_mc_big_comp_epols", "av_nurec_nomb_mc", fit_res, parameter_names=["e_pol_L", "e_pol_R", "e_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                            "new_share_high_ppol_3ab",
                                            "old_share_high_ppol_3ab",
                                            "new_share_low_ppol_3ab",
                                            "old_share_low_ppol_3ab",
                                            "new_share_no_ppol_3ab",
                                            "old_share_no_ppol_3ab",
                                            "equal_share_high_ppol_3ab",
                                            "equal_share_low_ppol_3ab",
                                            "no_pol_3ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("av_nurec_nomb_mc_big_comp_ppols", "av_nurec_nomb_mc", fit_res, parameter_names=["p_pol_L", "p_pol_R", "p_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                            "new_share_high_ppol_3ab",
                                            "old_share_high_ppol_3ab",
                                            "new_share_low_ppol_3ab",
                                            "old_share_low_ppol_3ab",
                                            "new_share_no_ppol_3ab",
                                            "old_share_no_ppol_3ab",
                                            "equal_share_high_ppol_3ab",
                                            "equal_share_low_ppol_3ab",
                                            "no_pol_3ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
# Out:
# <div id="root_plot_1771778979542" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979542() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(44116,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979542', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979542();
# </script>
# <div id="root_plot_1771778979549" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979549() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(41668,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979549', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979549();
# </script>
# <div id="root_plot_1771778979554" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979554() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(47422,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979554', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979554();
# </script>
# <div id="root_plot_1771778979558" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979558() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43746,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979558', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979558();
# </script>
# <div id="root_plot_1771778979562" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979562() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43690,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979562', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979562();
# </script>
# <div id="root_plot_1771778979567" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979567() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(44112,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979567', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979567();
# </script>
# <div id="root_plot_1771778979571" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979571() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(41662,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979571', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979571();
# </script>
# <div id="root_plot_1771778979575" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979575() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(47440,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979575', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979575();
# </script>
# <div id="root_plot_1771778979580" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979580() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43763,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979580', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979580();
# </script>
# <div id="root_plot_1771778979585" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979585() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43690,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979585', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979585();
# </script>
# <div id="root_plot_1771778979589" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979589() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(44116,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979589', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979589();
# </script>
# <div id="root_plot_1771778979593" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979593() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(41664,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979593', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979593();
# </script>
# <div id="root_plot_1771778979598" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979598() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(45503,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979598', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979598();
# </script>
# <div id="root_plot_1771778979602" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979602() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(42762,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979602', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979602();
# </script>
# <div id="root_plot_1771778979606" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778979606() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(42762,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778979606', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778979606();
# </script>

# %%
more_canvs.append(draw_overlaid_stacks("av_nurec_nomb_mc_big_comp_TGC", "av_nurec_nomb_mc_big_comp_TGC", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, y_max=1.95e-3, legend_columns=2, legend_pos=(0.16, 0.71, 0.94, 0.91), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("av_nurec_nomb_mc_big_comp_mW", "av_nurec_nomb_mc_big_comp_mW", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_columns=2, legend_pos=(0.16, 0.15, 0.94, 0.40), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("av_nurec_nomb_mc_big_comp_pols", "av_nurec_nomb_mc_big_comp_pols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("av_nurec_nomb_mc_big_comp_epols", "av_nurec_nomb_mc_big_comp_epols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.46, 0.38, 0.93, 0.89), y_max=1.8e-2, extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("av_nurec_nomb_mc_big_comp_ppols", "av_nurec_nomb_mc_big_comp_ppols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, y_max=1.8e-2, extra_legend_texts=extra_legend_text))
# Out:
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/av_nurec_nomb_mc_big_comp_TGC_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/av_nurec_nomb_mc_big_comp_TGC_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/av_nurec_nomb_mc_big_comp_mW_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/av_nurec_nomb_mc_big_comp_mW_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/av_nurec_nomb_mc_big_comp_pols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/av_nurec_nomb_mc_big_comp_pols_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/av_nurec_nomb_mc_big_comp_epols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/av_nurec_nomb_mc_big_comp_epols_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/av_nurec_nomb_mc_big_comp_ppols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/av_nurec_nomb_mc_big_comp_ppols_overlaid_stacks.pdf has been created
# <div id="root_plot_1771778980167" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980167() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(90811,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980167', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980167();
# </script>
# <div id="root_plot_1771778980175" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980175() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(83483,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980175', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980175();
# </script>
# <div id="root_plot_1771778980179" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980179() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(74277,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980179', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980179();
# </script>
# <div id="root_plot_1771778980182" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980182() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(66885,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980182', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980182();
# </script>
# <div id="root_plot_1771778980184" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980184() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(66750,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980184', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980184();
# </script>

# %%
local_dict2 = {
    "mlvec_clean_brems_reco": "Best reco CC20",
    "mlvec_clean_brems_reco_cc10": "Best reco CC10",
    "av_nurec_nomb_mc": "MC CC20",
    "av_nurec_nomb_mc_cc10": "MC CC10",
    "no_pol_3ab": "P(0,0), 3 ab^{-1}",
    "new_share_high_ppol_3ab": "P(#pm0.8,#pm0.6), (5%,45%,45%,5%), 3 ab^{-1}",
}
for k in ["free_pol", "constrained_pol", "fixed_pol"]:
    fit_res = fit_results[k]
    p = plotters[k]
    p.draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_mc_cc10_vs_cc20", "no_pol_3ab", fit_res, oo_names=[
        "av_nurec_nomb_mc",
        "av_nurec_nomb_mc_cc10",
    ], parameter_names=[
        "g1z",
        "ka",
        "la",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27),)
    # reco
    p.draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_reco_cc10_vs_cc20", "no_pol_3ab", fit_res, oo_names=[
        "mlvec_clean_brems_reco",
        "mlvec_clean_brems_reco_cc10",
    ], parameter_names=[
        "g1z",
        "ka",
        "la",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27))
    p.draw_plots_oo_names_per_run_name("new_share_high_ppol_3ab_TGC_mc_cc10_vs_cc20", "new_share_high_ppol_3ab", fit_res, oo_names=[
        "av_nurec_nomb_mc",
        "av_nurec_nomb_mc_cc10",
    ], parameter_names=[
        "g1z",
        "ka",
        "la",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27),)
    # reco
    p.draw_plots_oo_names_per_run_name("new_share_high_ppol_3ab_TGC_reco_cc10_vs_cc20", "new_share_high_ppol_3ab", fit_res, oo_names=[
        "mlvec_clean_brems_reco",
        "mlvec_clean_brems_reco_cc10",
    ], parameter_names=[
        "g1z",
        "ka",
        "la",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27))
# Out:
# <div id="root_plot_1771778980302" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980302() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25619,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980302', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980302();
# </script>
# <div id="root_plot_1771778980305" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980305() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25629,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980305', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980305();
# </script>
# <div id="root_plot_1771778980307" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980307() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25645,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980307', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980307();
# </script>
# <div id="root_plot_1771778980311" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980311() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25658,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980311', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980311();
# </script>
# <div id="root_plot_1771778980315" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980315() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25620,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980315', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980315();
# </script>
# <div id="root_plot_1771778980318" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980318() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25633,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980318', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980318();
# </script>
# <div id="root_plot_1771778980322" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980322() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25640,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980322', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980322();
# </script>
# <div id="root_plot_1771778980326" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980326() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25657,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980326', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980326();
# </script>
# <div id="root_plot_1771778980329" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980329() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25617,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980329', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980329();
# </script>
# <div id="root_plot_1771778980332" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980332() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25630,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980332', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980332();
# </script>
# <div id="root_plot_1771778980335" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980335() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25645,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980335', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980335();
# </script>
# <div id="root_plot_1771778980337" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778980337() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25659,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778980337', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778980337();
# </script>

# %%
more_canvs.append(draw_overlaid_stacks("no_pol_3ab_TGC_mc_cc10_vs_cc20", "no_pol_3ab_TGC_mc_cc10_vs_cc20", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.17, 0.70, 0.52, 0.85)))
more_canvs.append(draw_overlaid_stacks("no_pol_3ab_TGC_reco_cc10_vs_cc20", "no_pol_3ab_TGC_reco_cc10_vs_cc20", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.17, 0.70, 0.52, 0.85)))
# Out:
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_mc_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_mc_cc10_vs_cc20_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_reco_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_TGC_reco_cc10_vs_cc20_overlaid_stacks.pdf has been created
# <div id="root_plot_1771779239699" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771779239699() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(39375,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771779239699', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771779239699();
# </script>
# <div id="root_plot_1771779239705" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771779239705() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(39385,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771779239705', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771779239705();
# </script>

# %%
more_canvs.append(draw_overlaid_stacks("new_share_high_ppol_3ab_TGC_mc_cc10_vs_cc20", "new_share_high_ppol_3ab_TGC_mc_cc10_vs_cc20", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.17, 0.70, 0.52, 0.85)))
more_canvs.append(draw_overlaid_stacks("new_share_high_ppol_3ab_TGC_reco_cc10_vs_cc20", "new_share_high_ppol_3ab_TGC_reco_cc10_vs_cc20", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.17, 0.70, 0.52, 0.85)))
# Out:
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/new_share_high_ppol_3ab_TGC_mc_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/new_share_high_ppol_3ab_TGC_mc_cc10_vs_cc20_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/new_share_high_ppol_3ab_TGC_reco_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/new_share_high_ppol_3ab_TGC_reco_cc10_vs_cc20_overlaid_stacks.pdf has been created
# <div id="root_plot_1771779288331" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771779288331() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(39395,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771779288331', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771779288331();
# </script>
# <div id="root_plot_1771779288337" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771779288337() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(39409,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771779288337', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771779288337();
# </script>

# %%
for k in ["free_pol", "constrained_pol"]:
    fit_res = fit_results[k]
    p = plotters[k]
    p.draw_plots_oo_names_per_run_name("no_pol_3ab_pol_mc_cc10_vs_cc20", "no_pol_3ab", fit_res, oo_names=[
        "av_nurec_nomb_mc",
        "av_nurec_nomb_mc_cc10",
    ], parameter_names=[
        "e_pol_0",
        "p_pol_0",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27), x_label_dict=x_axis_label_dict)
    # reco
    p.draw_plots_oo_names_per_run_name("no_pol_3ab_pol_reco_cc10_vs_cc20", "no_pol_3ab", fit_res, oo_names=[
        "mlvec_clean_brems_reco",
        "mlvec_clean_brems_reco_cc10",
    ], parameter_names=[
        "e_pol_0",
        "p_pol_0",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27), x_label_dict=x_axis_label_dict)
    # polarised
    p.draw_plots_oo_names_per_run_name("new_share_high_ppol_3ab_pol_mc_cc10_vs_cc20", "new_share_high_ppol_3ab", fit_res, oo_names=[
        "av_nurec_nomb_mc",
        "av_nurec_nomb_mc_cc10",
    ], parameter_names=[
        "e_pol_L",
        "e_pol_R",
        "p_pol_L",
        "p_pol_R",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27), x_label_dict=x_axis_label_dict)
    # reco
    p.draw_plots_oo_names_per_run_name("new_share_high_ppol_3ab_pol_reco_cc10_vs_cc20", "new_share_high_ppol_3ab", fit_res, oo_names=[
        "mlvec_clean_brems_reco",
        "mlvec_clean_brems_reco_cc10",
    ], parameter_names=[
        "e_pol_L",
        "e_pol_R",
        "p_pol_L",
        "p_pol_R",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27), x_label_dict=x_axis_label_dict)
# Out:
# <div id="root_plot_1771778981059" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981059() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25368,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981059', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981059();
# </script>
# <div id="root_plot_1771778981064" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981064() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25375,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981064', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981064();
# </script>
# <div id="root_plot_1771778981069" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981069() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(26201,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981069', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981069();
# </script>
# <div id="root_plot_1771778981073" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981073() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(26214,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981073', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981073();
# </script>
# <div id="root_plot_1771778981075" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981075() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25385,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981075', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981075();
# </script>
# <div id="root_plot_1771778981077" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981077() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25395,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981077', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981077();
# </script>
# <div id="root_plot_1771778981078" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981078() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(26211,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981078', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981078();
# </script>
# <div id="root_plot_1771778981080" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981080() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(26225,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981080', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981080();
# </script>

# %%
more_canvs.append(draw_overlaid_stacks("no_pol_3ab_pol_mc_cc10_vs_cc20", "no_pol_3ab_pol_mc_cc10_vs_cc20", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.19, 0.22, 0.61, 0.36)))
more_canvs.append(draw_overlaid_stacks("no_pol_3ab_pol_reco_cc10_vs_cc20", "no_pol_3ab_pol_reco_cc10_vs_cc20", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.19, 0.22, 0.61, 0.36)))
more_canvs.append(draw_overlaid_stacks("new_share_high_ppol_3ab_pol_mc_cc10_vs_cc20", "new_share_high_ppol_3ab_pol_mc_cc10_vs_cc20", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.38, 0.72, 0.80, 0.87)))
more_canvs.append(draw_overlaid_stacks("new_share_high_ppol_3ab_pol_reco_cc10_vs_cc20", "new_share_high_ppol_3ab_pol_reco_cc10_vs_cc20", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.38, 0.72, 0.80, 0.87)))
# Out:
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_pol_mc_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_pol_mc_cc10_vs_cc20_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_pol_reco_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/no_pol_3ab_pol_reco_cc10_vs_cc20_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/new_share_high_ppol_3ab_pol_mc_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/new_share_high_ppol_3ab_pol_mc_cc10_vs_cc20_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/new_share_high_ppol_3ab_pol_reco_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/new_share_high_ppol_3ab_pol_reco_cc10_vs_cc20_overlaid_stacks.pdf has been created
# <div id="root_plot_1771778981518" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981518() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(32018,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981518', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981518();
# </script>
# <div id="root_plot_1771778981524" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981524() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(32019,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981524', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981524();
# </script>
# <div id="root_plot_1771778981530" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981530() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(33646,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981530', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981530();
# </script>
# <div id="root_plot_1771778981533" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981533() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(33658,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981533', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981533();
# </script>

# %%
for k in ["free_pol", "constrained_pol", "fixed_pol"]:
    fit_res = fit_results[k]
    p = plotters[k]
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_TGC", "mlvec_clean_brems_reco", fit_res, parameter_names=["g1z", "ka", "la", ], legend_pars=(0.7,0.55,1.,1.), legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_mW", "mlvec_clean_brems_reco", fit_res, parameter_names=["mW", ], legend_pars=(0.7, 0., 1., 0.45),
                                  legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_epols", "mlvec_clean_brems_reco", fit_res, parameter_names=["e_pol_L", "e_pol_R", "e_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_ppols", "mlvec_clean_brems_reco", fit_res, parameter_names=["p_pol_L", "p_pol_R", "p_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
# Out:
# <div id="root_plot_1771778981663" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981663() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28401,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981663', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981663();
# </script>
# <div id="root_plot_1771778981672" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981672() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27468,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981672', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981672();
# </script>
# <div id="root_plot_1771778981676" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981676() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28256,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981676', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981676();
# </script>
# <div id="root_plot_1771778981680" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981680() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28258,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981680', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981680();
# </script>
# <div id="root_plot_1771778981683" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981683() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28399,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981683', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981683();
# </script>
# <div id="root_plot_1771778981685" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981685() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27468,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981685', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981685();
# </script>
# <div id="root_plot_1771778981688" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981688() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28267,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981688', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981688();
# </script>
# <div id="root_plot_1771778981690" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981690() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28269,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981690', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981690();
# </script>
# <div id="root_plot_1771778981693" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981693() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28393,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981693', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981693();
# </script>
# <div id="root_plot_1771778981695" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981695() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27465,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981695', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981695();
# </script>
# <div id="root_plot_1771778981698" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981698() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27912,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981698', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981698();
# </script>
# <div id="root_plot_1771778981701" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778981701() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27912,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778981701', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778981701();
# </script>

# %%
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_TGC", "mlvec_clean_brems_reco_small_comp_TGC", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, y_max=2.3e-3, legend_columns=2, legend_pos=(0.16, 0.71, 0.94, 0.91), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_mW", "mlvec_clean_brems_reco_small_comp_mW", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_columns=2, legend_pos=(0.16, 0.15, 0.94, 0.40), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_epols", "mlvec_clean_brems_reco_small_comp_epols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.46, 0.38, 0.93, 0.89), y_max=1.8e-2, extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_ppols", "mlvec_clean_brems_reco_small_comp_ppols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, y_max=1.8e-2, extra_legend_texts=extra_legend_text))
# Out:
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_TGC_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_TGC_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_mW_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_mW_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_epols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_epols_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_ppols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_ppols_overlaid_stacks.pdf has been created
# <div id="root_plot_1771778982229" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982229() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(47846,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982229', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982229();
# </script>
# <div id="root_plot_1771778982235" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982235() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(45084,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982235', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982235();
# </script>
# <div id="root_plot_1771778982241" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982241() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(37980,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982241', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982241();
# </script>
# <div id="root_plot_1771778982244" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982244() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(37975,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982244', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982244();
# </script>

# %%
for k in ["free_pol", "constrained_pol", "fixed_pol"]:
    fit_res = fit_results[k]
    p = plotters[k]
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_TGC_cc10", "mlvec_clean_brems_reco_cc10", fit_res, parameter_names=["g1z", "ka", "la", ], legend_pars=(0.7,0.55,1.,1.), legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_mW_cc10", "mlvec_clean_brems_reco_cc10", fit_res, parameter_names=["mW", ], legend_pars=(0.7, 0., 1., 0.45),
                                  legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_epols_cc10", "mlvec_clean_brems_reco_cc10", fit_res, parameter_names=["e_pol_L", "e_pol_R", "e_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_ppols_cc10", "mlvec_clean_brems_reco_cc10", fit_res, parameter_names=["p_pol_L", "p_pol_R", "p_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
# Out:
# <div id="root_plot_1771778982365" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982365() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28380,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982365', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982365();
# </script>
# <div id="root_plot_1771778982368" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982368() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27447,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982368', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982368();
# </script>
# <div id="root_plot_1771778982373" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982373() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28237,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982373', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982373();
# </script>
# <div id="root_plot_1771778982376" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982376() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28233,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982376', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982376();
# </script>
# <div id="root_plot_1771778982379" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982379() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28384,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982379', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982379();
# </script>
# <div id="root_plot_1771778982381" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982381() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27449,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982381', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982381();
# </script>
# <div id="root_plot_1771778982383" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982383() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28251,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982383', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982383();
# </script>
# <div id="root_plot_1771778982385" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982385() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28253,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982385', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982385();
# </script>
# <div id="root_plot_1771778982388" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982388() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28377,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982388', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982388();
# </script>
# <div id="root_plot_1771778982390" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982390() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27451,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982390', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982390();
# </script>
# <div id="root_plot_1771778982392" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982392() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27897,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982392', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982392();
# </script>
# <div id="root_plot_1771778982395" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982395() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27897,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982395', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982395();
# </script>

# %%
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_TGC_cc10", "mlvec_clean_brems_reco_small_comp_TGC_cc10", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, y_max=6.5e-3, legend_columns=2, legend_pos=(0.16, 0.71, 0.94, 0.91), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_mW_cc10", "mlvec_clean_brems_reco_small_comp_mW_cc10", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_columns=2, legend_pos=(0.16, 0.15, 0.94, 0.40), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_epols_cc10", "mlvec_clean_brems_reco_small_comp_epols_cc10", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.46, 0.38, 0.93, 0.89), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_ppols_cc10", "mlvec_clean_brems_reco_small_comp_ppols_cc10", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, extra_legend_texts=extra_legend_text))
# Out:
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_TGC_cc10_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_TGC_cc10_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_mW_cc10_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_mW_cc10_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_epols_cc10_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_epols_cc10_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_ppols_cc10_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/new_fit_results_bars/mlvec_clean_brems_reco_small_comp_ppols_cc10_overlaid_stacks.pdf has been created
# <div id="root_plot_1771778982805" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982805() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(47828,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982805', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982805();
# </script>
# <div id="root_plot_1771778982812" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982812() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(45061,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982812', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982812();
# </script>
# <div id="root_plot_1771778982817" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982817() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(37996,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982817', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982817();
# </script>
# <div id="root_plot_1771778982820" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771778982820() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(37993,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771778982820', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771778982820();
# </script>
