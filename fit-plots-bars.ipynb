# %%
import ROOT
from fitHelper import Plotter, draw_overlaid_stacks
# Out:
# OBJ: TStyle	ildStyle	ILD Style : 0 at: 0x8b9e4a0
# OBJ: TStyle	ildStyle	ILD Style : 0 at: 0x8dbb010

# %%
def get_fit_results(fitres_dir: str, run_conf_names: list[str], lumi_list, oo_names):
    fit_results = {}
    for oo_name in oo_names:
        fs = {}
        for name in run_conf_names:
            for run_ab in lumi_list:
                run_name = f"{name}_{run_ab}ab"
                with ROOT.TFile.Open(f"{fitres_dir}/{oo_name}_{run_name}_fitres.root") as in_file:
                    fit_res = in_file.Get("fit_result_nominal")
                fs[run_name] = fit_res
        fit_results[oo_name] = fs
    return fit_results

# %%
run_conf_names = [
    "new_share_high_ppol",
    "old_share_high_ppol",
    "new_share_low_ppol",
    "old_share_low_ppol",
    "new_share_no_ppol",
    "old_share_no_ppol",
    "equal_share_high_ppol",
    "equal_share_low_ppol",
    "no_pol"
]
lumi_list = [2, 3, 10.8]

# %%
oo_names = [
    "mlvec_reco",
    "reco",
    "mlvec_reco_jm",
    "reco_jm",
    "mlvec_clean_reco",
    "clean_reco",
    "mlvec_clean_brems_reco",
    "clean_brems_reco",
    # "kinfit_clean_reco",
    "mlvec_clean_reco_jm",
    "clean_reco_jm",
    "clean_brems_reco_jm",
    "mlvec_clean_brems_reco_jm",
    # "kinfit_clean_reco_jm",
    "mlvec_cheat_clean_reco",
    "cheat_clean_reco",
    "mlvec_cheat_clean_reco_jm",
    "cheat_clean_reco_jm",
    "mc",
    "nomb_mc",
    "nomb_mc_rlep",
    "nomb_mc_rlep_gamma",
    "nomb_mc_rlep_brems",
    "nomb_mc_rlep_cheated_brems",
    "nurec_nomb_mc",
    "nurec_nomb_mc_rlep",
    "nurec_nomb_mc_rlep_gamma",
    "nurec_nomb_mc_rlep_brems",
    "nurec_nomb_mc_rlep_cheated_brems",
    "nurec_post94_mc",
    "av_mc",
    "av_nomb_mc",
    "av_nomb_mc_rlep",
    "av_nomb_mc_rlep_gamma",
    "av_nomb_mc_rlep_brems",
    "av_nomb_mc_rlep_cheated_brems",
    "av_nurec_nomb_mc",
    "av_nurec_nomb_mc_rlep",
    "av_nurec_nomb_mc_rlep_gamma",
    "av_nurec_nomb_mc_rlep_brems",
    "av_nurec_nomb_mc_rlep_cheated_brems",
    "av_nurec_post94_mc",
    "av_nurec_nomb_mc_cc10",
    "mlvec_clean_brems_reco_cc10",
    "mlvec_clean_brems_reco_san",
]

reduced_oo_names = [
    "mlvec_clean_brems_reco",
    "mlvec_clean_brems_reco_jm",
    "mlvec_clean_brems_reco_cc10",
    "av_nurec_nomb_mc",
    "nurec_nomb_mc",
    "av_nurec_nomb_mc_cc10",
]

# %%
prefix = "data/fit_results"
fit_results = {
    "free_pol": get_fit_results(f"{prefix}/free_pol/", run_conf_names, lumi_list, reduced_oo_names),
    "constrained_pol": get_fit_results(f"{prefix}/pol_constrained_2.5em3/", run_conf_names, lumi_list, oo_names),
    "constrained_pol_fixed_mW": get_fit_results(f"{prefix}/pol_constrained_2.5em3_fixed_mW/", run_conf_names, lumi_list, reduced_oo_names),
    "constrained_pol_constrained_mW": get_fit_results(f"{prefix}/pol_constrained_2.5em3_mW_constrained_2MeV/", run_conf_names, lumi_list, reduced_oo_names),
    "fixed_pol": get_fit_results(f"{prefix}/fixed_pol/", run_conf_names, lumi_list, reduced_oo_names),
    "fixed_mW": get_fit_results(f"{prefix}/fixed_mW/", run_conf_names, lumi_list, reduced_oo_names),
}

# %%
legend_name_dict_oo = {
    "reco": "Reco, E-scheme",
    "mlvec_reco": "Reco, P-scheme",
    "clean_reco": "Reco, E-scheme, BIB-removal",
    "mlvec_clean_reco": "Reco, P-scheme, BIB-removal",
    "clean_brems_reco": "Reco, E-scheme, BIB-removal + brems",
    "mlvec_clean_brems_reco": "Reco, P-scheme, BIB-removal + brems",
    "cheat_clean_reco": "Reco, E-scheme, cheat BIB-removal",
    "mlvec_cheat_clean_reco": "Reco, P-scheme, cheat BIB-removal",
    "mlvec_clean_brems_reco_jm": "Best reco + perfect jet-charge",
    "mlvec_clean_brems_reco_cc10": "Best reco, WW only",
    "av_nurec_nomb_mc": "MC",
    "av_mc": "MC + cheat #sqrt{s}",
    "nurec_nomb_mc": "MC + perfect jet-charge",
    "av_nurec_nomb_mc_cc10": "MC, WW only",
    "av_nurec_nomb_mc_rlep": "MC + Reco lep",
    "av_nurec_nomb_mc_rlep_gamma": "MC + Reco lep, iso-#gamma brems",
    "av_nurec_nomb_mc_rlep_brems": "MC + Reco lep, window brems",
    "av_nurec_nomb_mc_rlep_cheated_brems": "MC + Reco lep, cheated brems",
}
name_dict_run_confs = {
    "no_pol": "P(0,0)",
    "new_share_high_ppol": "P(#pm0.8,#pm0.6), (5%,45%,45%,5%)",
    "old_share_high_ppol": "P(#pm0.8,#pm0.6), (5%,67.5%,22.5%,5%)",
    "new_share_low_ppol": "P(#pm0.8,#pm0.3), (5%,45%,45%,5%)",
    "old_share_low_ppol": "P(#pm0.8,#pm0.3), (5%,67.5%,22.5%,5%)",
    "new_share_no_ppol": "P(#pm0.8,0), (50%,50%)",
    "old_share_no_ppol": "P(#pm0.8,0), (72.5%,27.5%)",
    "equal_share_high_ppol": "P(#pm0.8,#pm0.6), (25%,25%,25%,25%)",
    "equal_share_low_ppol": "P(#pm0.8,#pm0.3), (25%,25%,25%,25%)",
}
legend_name_dict_oo |= {f"{name}_{run_ab}ab": f"{text}, {run_ab} ab^{{-1}}" for run_ab in lumi_list for name, text in name_dict_run_confs.items()}

x_axis_label_dict = {
    "g1z": "g_{1}^{Z}",
    "ka": "#kappa_{#gamma}",
    "la": "#lambda_{#gamma}",
    "mW": "m_{W}",
    "e_pol_L": "P_{e^{-}}^{-}",
    "e_pol_R": "P_{e^{-}}^{+}",
    "e_pol_0": "P_{e^{-}}^{0}",
    "p_pol_L": "P_{e^{+}}^{-}",
    "p_pol_R": "P_{e^{+}}^{+}",
    "p_pol_0": "P_{e^{+}}^{0}",
}

# %%
plotters = {key: Plotter() for key in fit_results}
plot_dir = "plots/fit_results_bars"

# %%
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_mc", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "mc",
    "av_mc",
], parameter_names=[
    "g1z",
    "ka",
    "la",
], legend_name_dict=legend_name_dict_oo, x_label_dict=x_axis_label_dict)
# Out:
# <div id="root_plot_1771714739854" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714739854() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25568,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714739854', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714739854();
# </script>

# %%
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_mc_ISR", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "av_mc",
    "av_nurec_nomb_mc"
], parameter_names=[
    "g1z",
    "ka",
    "la",
    "mW"
], legend_name_dict=legend_name_dict_oo, x_label_dict=x_axis_label_dict, plot_dir=plot_dir)
# Out:
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_mc_ISR_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_mc_ISR.pdf has been created
# <div id="root_plot_1771714740019" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714740019() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(26017,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714740019', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714740019();
# </script>

# %%
# mlvec and BIB-removal
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_mlvec_or_not", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "mlvec_reco",
    "reco",
    "mlvec_clean_reco",
    "clean_reco",
    "mlvec_cheat_clean_reco",
    "cheat_clean_reco",
    # "mlvec_clean_brems_reco",
    # "clean_brems_reco",
], parameter_names=[
    "g1z",
    "ka",
    "la",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.14, 0.68, 0.42), plot_dir=plot_dir, x_label_dict=x_axis_label_dict)
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_mW_mlvec_or_not", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "mlvec_reco",
    "reco",
    "mlvec_clean_reco",
    "clean_reco",
    "mlvec_cheat_clean_reco",
    "cheat_clean_reco",
    # "mlvec_clean_brems_reco",
    # "clean_brems_reco",
], parameter_names=[
    "mW",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.14, 0.68, 0.42), plot_dir=plot_dir, x_label_dict=x_axis_label_dict, unit="GeV")
# Out:
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_mlvec_or_not_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_mlvec_or_not.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_mW_mlvec_or_not_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_mW_mlvec_or_not.pdf has been created
# <div id="root_plot_1771714740226" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714740226() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(35962,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714740226', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714740226();
# </script>
# <div id="root_plot_1771714740229" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714740229() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(34282,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714740229', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714740229();
# </script>

# %%
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_brems_mc", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "av_nurec_nomb_mc_rlep",
    "av_nurec_nomb_mc_rlep_gamma",
    "av_nurec_nomb_mc_rlep_brems",
    "av_nurec_nomb_mc_rlep_cheated_brems",
    "av_nurec_nomb_mc",
], parameter_names=[
    "g1z",
    "ka",
    "la",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.14, 0.68, 0.42), plot_dir=plot_dir, x_label_dict=x_axis_label_dict)
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_mW_brems_mc", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "av_nurec_nomb_mc_rlep",
    "av_nurec_nomb_mc_rlep_gamma",
    "av_nurec_nomb_mc_rlep_brems",
    "av_nurec_nomb_mc_rlep_cheated_brems",
    "av_nurec_nomb_mc",
], parameter_names=[
    "mW",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.14, 0.68, 0.42), plot_dir=plot_dir, x_label_dict=x_axis_label_dict, unit="GeV")
# Out:
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_brems_mc_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_brems_mc.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_mW_brems_mc_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_mW_brems_mc.pdf has been created
# <div id="root_plot_1771714740408" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714740408() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(33340,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714740408', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714740408();
# </script>
# <div id="root_plot_1771714740414" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714740414() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(31909,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714740414', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714740414();
# </script>

# %%
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_brems_reco", "no_pol_3ab", fit_results["constrained_pol"]  , oo_names=[
    "mlvec_clean_reco",
    # "clean_reco",
    "mlvec_clean_brems_reco",
    # "clean_brems_reco",
], parameter_names=[
    "g1z",
    "ka",
    "la",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.14, 0.68, 0.42), plot_dir=plot_dir, x_label_dict=x_axis_label_dict)
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_mW_brems_reco", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "mlvec_clean_reco",
    # "clean_reco",
    "mlvec_clean_brems_reco",
    # "clean_brems_reco",
], parameter_names=[
    "mW",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.14, 0.68, 0.42), plot_dir=plot_dir, x_label_dict=x_axis_label_dict, unit="GeV")
# Out:
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_brems_reco_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_brems_reco.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_mW_brems_reco_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_mW_brems_reco.pdf has been created
# <div id="root_plot_1771714740601" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714740601() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25568,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714740601', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714740601();
# </script>
# <div id="root_plot_1771714740605" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714740605() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(24887,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714740605', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714740605();
# </script>

# %%
# final reco to mc comparison
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_mW_reco_mc", "no_pol_3ab", fit_results["constrained_pol"]  , oo_names=[
    "mlvec_clean_brems_reco",
    "av_nurec_nomb_mc",
], parameter_names=[
    "g1z",
    "ka",
    "la",
    "mW",
], legend_name_dict=legend_name_dict_oo, legend_pars=(0.17, 0.60, 0.68, 0.87), plot_dir=plot_dir, x_label_dict=x_axis_label_dict)
# Out:
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_mW_reco_mc_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_mW_reco_mc.pdf has been created
# <div id="root_plot_1771714740749" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714740749() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25982,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714740749', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714740749();
# </script>

# %%
local_dict = {
    "mlvec_clean_brems_reco": "Best reco",
    "mlvec_clean_brems_reco_jm": "Best reco + perfect jet-charge",
    "av_nurec_nomb_mc": "MC",
    "nurec_nomb_mc": "MC + perfect jet-charge",
    "no_pol_3ab": "P(0,0), 3 ab^{-1}",
}
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_jet_charge", "no_pol_3ab", fit_results["constrained_pol"]  , oo_names=[
    "mlvec_clean_brems_reco",
    "mlvec_clean_brems_reco_jm",
    "av_nurec_nomb_mc",
    "nurec_nomb_mc",
], parameter_names=[
    "g1z",
    "ka",
    "la",
], legend_name_dict=local_dict, legend_pars=(0.17, 0.14, 0.68, 0.41), plot_dir=plot_dir, x_label_dict=x_axis_label_dict)
plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_mW_jet_charge", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
    "mlvec_clean_brems_reco",
    "mlvec_clean_brems_reco_jm",
    "av_nurec_nomb_mc",
    "nurec_nomb_mc",
], parameter_names=[
    "mW",
], legend_name_dict=local_dict, legend_pars=(0.17, 0.14, 0.68, 0.41), plot_dir=plot_dir, x_label_dict=x_axis_label_dict, unit="GeV")
# plotters["constrained_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_pol_jet_charge", "no_pol_3ab", fit_results["constrained_pol"], oo_names=[
plotters["free_pol"].draw_plots_oo_names_per_run_name("no_pol_3ab_pol_jet_charge", "no_pol_3ab", fit_results["free_pol"], oo_names=[
    "mlvec_clean_brems_reco",
    "mlvec_clean_brems_reco_jm",
    "av_nurec_nomb_mc",
    "nurec_nomb_mc",
], parameter_names=[
    "e_pol_0",
    "p_pol_0",
], legend_name_dict=local_dict, legend_pars=(0.17, 0.14, 0.68, 0.41), plot_dir=plot_dir, x_label_dict=x_axis_label_dict, unit="GeV")
# plotters["constrained_pol"].draw_plots_oo_names_per_run_name("new_share_low_ppol_3ab_pol_jet_charge", "new_share_low_ppol_3ab", fit_results["constrained_pol"], oo_names=[
plotters["free_pol"].draw_plots_oo_names_per_run_name("new_share_low_ppol_3ab_pol_jet_charge", "new_share_low_ppol_3ab", fit_results["free_pol"], oo_names=[
    "mlvec_clean_brems_reco",
    "mlvec_clean_brems_reco_jm",
    "av_nurec_nomb_mc",
    "nurec_nomb_mc",
], parameter_names=[
    "e_pol_L",
    "e_pol_R",
    "p_pol_L",
    "p_pol_R",
], legend_name_dict=local_dict, legend_pars=(0.17, 0.14, 0.68, 0.41), plot_dir=plot_dir, x_label_dict=x_axis_label_dict, unit="GeV")
# Out:
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_jet_charge_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_jet_charge.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_mW_jet_charge_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_mW_jet_charge.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_pol_jet_charge_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_pol_jet_charge.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/new_share_low_ppol_3ab_pol_jet_charge_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/new_share_low_ppol_3ab_pol_jet_charge.pdf has been created
# <div id="root_plot_1771714825211" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714825211() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(30925,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714825211', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714825211();
# </script>
# <div id="root_plot_1771714825217" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714825217() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(29742,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714825217', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714825217();
# </script>
# <div id="root_plot_1771714825222" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714825222() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(30347,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714825222', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714825222();
# </script>
# <div id="root_plot_1771714825224" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714825224() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(31764,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714825224', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714825224();
# </script>

# %%
for k in ["free_pol", "constrained_pol", "fixed_pol"]:
    fit_res = fit_results[k]
    p = plotters[k]
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_big_comp_TGC", "mlvec_clean_brems_reco", fit_res, parameter_names=["g1z", "ka", "la", ], legend_pars=(0.7,0.55,1.,1.), legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_high_ppol_3ab",
                                      "old_share_high_ppol_3ab",
                                      "new_share_low_ppol_3ab",
                                      "old_share_low_ppol_3ab",
                                      "new_share_no_ppol_3ab",
                                      "old_share_no_ppol_3ab",
                                      "equal_share_high_ppol_3ab",
                                      "equal_share_low_ppol_3ab",
                                      "no_pol_3ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_big_comp_mW", "mlvec_clean_brems_reco", fit_res, parameter_names=["mW", ], legend_pars=(0.7, 0., 1., 0.45),
                                  legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_high_ppol_3ab",
                                      "old_share_high_ppol_3ab",
                                      "new_share_low_ppol_3ab",
                                      "old_share_low_ppol_3ab",
                                      "new_share_no_ppol_3ab",
                                      "old_share_no_ppol_3ab",
                                      "equal_share_high_ppol_3ab",
                                      "equal_share_low_ppol_3ab",
                                      "no_pol_3ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_big_comp_pols", "mlvec_clean_brems_reco", fit_res, parameter_names=["e_pol_L", "e_pol_R", "e_pol_0", "p_pol_L", "p_pol_R", "p_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                            "new_share_high_ppol_3ab",
                                            "old_share_high_ppol_3ab",
                                            "new_share_low_ppol_3ab",
                                            "old_share_low_ppol_3ab",
                                            "new_share_no_ppol_3ab",
                                            "old_share_no_ppol_3ab",
                                            "equal_share_high_ppol_3ab",
                                            "equal_share_low_ppol_3ab",
                                            "no_pol_3ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)

    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_big_comp_epols", "mlvec_clean_brems_reco", fit_res, parameter_names=["e_pol_L", "e_pol_R", "e_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                            "new_share_high_ppol_3ab",
                                            "old_share_high_ppol_3ab",
                                            "new_share_low_ppol_3ab",
                                            "old_share_low_ppol_3ab",
                                            "new_share_no_ppol_3ab",
                                            "old_share_no_ppol_3ab",
                                            "equal_share_high_ppol_3ab",
                                            "equal_share_low_ppol_3ab",
                                            "no_pol_3ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)

    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_big_comp_ppols", "mlvec_clean_brems_reco", fit_res, parameter_names=["p_pol_L", "p_pol_R", "p_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                            "new_share_high_ppol_3ab",
                                            "old_share_high_ppol_3ab",
                                            "new_share_low_ppol_3ab",
                                            "old_share_low_ppol_3ab",
                                            "new_share_no_ppol_3ab",
                                            "old_share_no_ppol_3ab",
                                            "equal_share_high_ppol_3ab",
                                            "equal_share_low_ppol_3ab",
                                            "no_pol_3ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
# Out:
# <div id="root_plot_1771714741339" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741339() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43951,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741339', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741339();
# </script>
# <div id="root_plot_1771714741344" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741344() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(41495,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741344', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741344();
# </script>
# <div id="root_plot_1771714741348" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741348() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(47241,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741348', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741348();
# </script>
# <div id="root_plot_1771714741353" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741353() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43574,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741353', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741353();
# </script>
# <div id="root_plot_1771714741357" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741357() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43501,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741357', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741357();
# </script>
# <div id="root_plot_1771714741363" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741363() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43943,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741363', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741363();
# </script>
# <div id="root_plot_1771714741367" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741367() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(41502,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741367', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741367();
# </script>
# <div id="root_plot_1771714741373" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741373() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(47266,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741373', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741373();
# </script>
# <div id="root_plot_1771714741377" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741377() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43589,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741377', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741377();
# </script>
# <div id="root_plot_1771714741382" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741382() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43520,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741382', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741382();
# </script>
# <div id="root_plot_1771714741387" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741387() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43944,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741387', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741387();
# </script>
# <div id="root_plot_1771714741392" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741392() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(41504,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741392', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741392();
# </script>
# <div id="root_plot_1771714741396" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741396() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(45339,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741396', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741396();
# </script>
# <div id="root_plot_1771714741401" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741401() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(42598,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741401', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741401();
# </script>
# <div id="root_plot_1771714741405" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714741405() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(42598,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714741405', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714741405();
# </script>

# %%
more_canvs = []
extra_legend_text = ["Free pol.", "Constrained pol.", "Fixed pol."]
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_big_comp_TGC", "mlvec_clean_brems_reco_big_comp_TGC", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, y_max=1.95e-3, legend_columns=2, legend_pos=(0.16, 0.71, 0.94, 0.91), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_big_comp_mW", "mlvec_clean_brems_reco_big_comp_mW", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_columns=2, legend_pos=(0.16, 0.15, 0.94, 0.40), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_big_comp_pols", "mlvec_clean_brems_reco_big_comp_pols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_big_comp_epols", "mlvec_clean_brems_reco_big_comp_epols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.46, 0.38, 0.93, 0.89), y_max=1.8e-2, extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_big_comp_ppols", "mlvec_clean_brems_reco_big_comp_ppols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, y_max=1.8e-2, extra_legend_texts=extra_legend_text))
# Out:
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_big_comp_TGC_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_big_comp_TGC_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_big_comp_mW_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_big_comp_mW_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_big_comp_pols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_big_comp_pols_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_big_comp_epols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_big_comp_epols_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_big_comp_ppols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_big_comp_ppols_overlaid_stacks.pdf has been created
# <div id="root_plot_1771714742629" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742629() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(90831,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742629', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742629();
# </script>
# <div id="root_plot_1771714742632" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742632() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(83515,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742632', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742632();
# </script>
# <div id="root_plot_1771714742634" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742634() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(74288,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742634', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742634();
# </script>
# <div id="root_plot_1771714742636" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742636() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(66904,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742636', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742636();
# </script>
# <div id="root_plot_1771714742638" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742638() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(66760,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742638', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742638();
# </script>

# %%
for k in ["free_pol", "constrained_pol", "fixed_pol"]:
    fit_res = fit_results[k]
    p = plotters[k]
    p.draw_plots_runs_per_oo_name("av_nurec_nomb_mc_big_comp_TGC", "av_nurec_nomb_mc", fit_res, parameter_names=["g1z", "ka", "la", ], legend_pars=(0.7,0.55,1.,1.), legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_high_ppol_3ab",
                                      "old_share_high_ppol_3ab",
                                      "new_share_low_ppol_3ab",
                                      "old_share_low_ppol_3ab",
                                      "new_share_no_ppol_3ab",
                                      "old_share_no_ppol_3ab",
                                      "equal_share_high_ppol_3ab",
                                      "equal_share_low_ppol_3ab",
                                      "no_pol_3ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("av_nurec_nomb_mc_big_comp_mW", "av_nurec_nomb_mc", fit_res, parameter_names=["mW", ], legend_pars=(0.7, 0., 1., 0.45),
                                  legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_high_ppol_3ab",
                                      "old_share_high_ppol_3ab",
                                      "new_share_low_ppol_3ab",
                                      "old_share_low_ppol_3ab",
                                      "new_share_no_ppol_3ab",
                                      "old_share_no_ppol_3ab",
                                      "equal_share_high_ppol_3ab",
                                      "equal_share_low_ppol_3ab",
                                      "no_pol_3ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("av_nurec_nomb_mc_big_comp_pols", "av_nurec_nomb_mc", fit_res, parameter_names=["e_pol_L", "e_pol_R", "e_pol_0", "p_pol_L", "p_pol_R", "p_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                            "new_share_high_ppol_3ab",
                                            "old_share_high_ppol_3ab",
                                            "new_share_low_ppol_3ab",
                                            "old_share_low_ppol_3ab",
                                            "new_share_no_ppol_3ab",
                                            "old_share_no_ppol_3ab",
                                            "equal_share_high_ppol_3ab",
                                            "equal_share_low_ppol_3ab",
                                            "no_pol_3ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("av_nurec_nomb_mc_big_comp_epols", "av_nurec_nomb_mc", fit_res, parameter_names=["e_pol_L", "e_pol_R", "e_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                            "new_share_high_ppol_3ab",
                                            "old_share_high_ppol_3ab",
                                            "new_share_low_ppol_3ab",
                                            "old_share_low_ppol_3ab",
                                            "new_share_no_ppol_3ab",
                                            "old_share_no_ppol_3ab",
                                            "equal_share_high_ppol_3ab",
                                            "equal_share_low_ppol_3ab",
                                            "no_pol_3ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("av_nurec_nomb_mc_big_comp_ppols", "av_nurec_nomb_mc", fit_res, parameter_names=["p_pol_L", "p_pol_R", "p_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                            "new_share_high_ppol_3ab",
                                            "old_share_high_ppol_3ab",
                                            "new_share_low_ppol_3ab",
                                            "old_share_low_ppol_3ab",
                                            "new_share_no_ppol_3ab",
                                            "old_share_no_ppol_3ab",
                                            "equal_share_high_ppol_3ab",
                                            "equal_share_low_ppol_3ab",
                                            "no_pol_3ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
# Out:
# <div id="root_plot_1771714742771" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742771() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(44118,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742771', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742771();
# </script>
# <div id="root_plot_1771714742779" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742779() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(41663,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742779', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742779();
# </script>
# <div id="root_plot_1771714742784" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742784() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(47416,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742784', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742784();
# </script>
# <div id="root_plot_1771714742788" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742788() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43749,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742788', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742788();
# </script>
# <div id="root_plot_1771714742792" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742792() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43672,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742792', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742792();
# </script>
# <div id="root_plot_1771714742796" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742796() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(44108,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742796', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742796();
# </script>
# <div id="root_plot_1771714742800" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742800() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(41668,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742800', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742800();
# </script>
# <div id="root_plot_1771714742804" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742804() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(47437,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742804', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742804();
# </script>
# <div id="root_plot_1771714742808" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742808() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43758,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742808', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742808();
# </script>
# <div id="root_plot_1771714742812" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742812() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(43692,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742812', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742812();
# </script>
# <div id="root_plot_1771714742816" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742816() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(44111,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742816', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742816();
# </script>
# <div id="root_plot_1771714742820" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742820() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(41667,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742820', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742820();
# </script>
# <div id="root_plot_1771714742824" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742824() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(45503,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742824', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742824();
# </script>
# <div id="root_plot_1771714742828" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742828() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(42762,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742828', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742828();
# </script>
# <div id="root_plot_1771714742832" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714742832() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(42762,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714742832', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714742832();
# </script>

# %%
more_canvs.append(draw_overlaid_stacks("av_nurec_nomb_mc_big_comp_TGC", "av_nurec_nomb_mc_big_comp_TGC", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, y_max=1.95e-3, legend_columns=2, legend_pos=(0.16, 0.71, 0.94, 0.91), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("av_nurec_nomb_mc_big_comp_mW", "av_nurec_nomb_mc_big_comp_mW", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_columns=2, legend_pos=(0.16, 0.15, 0.94, 0.40), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("av_nurec_nomb_mc_big_comp_pols", "av_nurec_nomb_mc_big_comp_pols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("av_nurec_nomb_mc_big_comp_epols", "av_nurec_nomb_mc_big_comp_epols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.46, 0.38, 0.93, 0.89), y_max=1.8e-2, extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("av_nurec_nomb_mc_big_comp_ppols", "av_nurec_nomb_mc_big_comp_ppols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, y_max=1.8e-2, extra_legend_texts=extra_legend_text))
# Out:
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/av_nurec_nomb_mc_big_comp_TGC_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/av_nurec_nomb_mc_big_comp_TGC_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/av_nurec_nomb_mc_big_comp_mW_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/av_nurec_nomb_mc_big_comp_mW_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/av_nurec_nomb_mc_big_comp_pols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/av_nurec_nomb_mc_big_comp_pols_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/av_nurec_nomb_mc_big_comp_epols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/av_nurec_nomb_mc_big_comp_epols_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/av_nurec_nomb_mc_big_comp_ppols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/av_nurec_nomb_mc_big_comp_ppols_overlaid_stacks.pdf has been created
# <div id="root_plot_1771714743348" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743348() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(90807,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743348', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743348();
# </script>
# <div id="root_plot_1771714743358" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743358() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(83488,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743358', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743358();
# </script>
# <div id="root_plot_1771714743363" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743363() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(74268,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743363', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743363();
# </script>
# <div id="root_plot_1771714743366" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743366() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(66885,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743366', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743366();
# </script>
# <div id="root_plot_1771714743368" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743368() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(66737,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743368', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743368();
# </script>

# %%
local_dict2 = {
    "mlvec_clean_brems_reco": "Best reco CC20",
    "mlvec_clean_brems_reco_cc10": "Best reco CC10",
    "av_nurec_nomb_mc": "MC CC20",
    "av_nurec_nomb_mc_cc10": "MC CC10",
    "no_pol_3ab": "P(0,0), 3 ab^{-1}",
    "new_share_high_ppol_3ab": "P(#pm0.8,#pm0.6), (5%,45%,45%,5%), 3 ab^{-1}",
}
for k in ["free_pol", "constrained_pol", "fixed_pol"]:
    fit_res = fit_results[k]
    p = plotters[k]
    p.draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_mc_cc10_vs_cc20", "no_pol_3ab", fit_res, oo_names=[
        "av_nurec_nomb_mc",
        "av_nurec_nomb_mc_cc10",
    ], parameter_names=[
        "g1z",
        "ka",
        "la",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27),)
    # reco
    p.draw_plots_oo_names_per_run_name("no_pol_3ab_TGC_reco_cc10_vs_cc20", "no_pol_3ab", fit_res, oo_names=[
        "mlvec_clean_brems_reco",
        "mlvec_clean_brems_reco_cc10",
    ], parameter_names=[
        "g1z",
        "ka",
        "la",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27))
    p.draw_plots_oo_names_per_run_name("new_share_high_ppol_3ab_TGC_mc_cc10_vs_cc20", "new_share_high_ppol_3ab", fit_res, oo_names=[
        "av_nurec_nomb_mc",
        "av_nurec_nomb_mc_cc10",
    ], parameter_names=[
        "g1z",
        "ka",
        "la",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27),)
    # reco
    p.draw_plots_oo_names_per_run_name("new_share_high_ppol_3ab_TGC_reco_cc10_vs_cc20", "new_share_high_ppol_3ab", fit_res, oo_names=[
        "mlvec_clean_brems_reco",
        "mlvec_clean_brems_reco_cc10",
    ], parameter_names=[
        "g1z",
        "ka",
        "la",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27))
# Out:
# <div id="root_plot_1771714743485" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743485() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25617,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743485', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743485();
# </script>
# <div id="root_plot_1771714743489" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743489() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25629,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743489', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743489();
# </script>
# <div id="root_plot_1771714743492" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743492() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25646,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743492', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743492();
# </script>
# <div id="root_plot_1771714743493" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743493() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25657,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743493', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743493();
# </script>
# <div id="root_plot_1771714743495" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743495() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25617,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743495', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743495();
# </script>
# <div id="root_plot_1771714743496" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743496() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25630,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743496', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743496();
# </script>
# <div id="root_plot_1771714743497" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743497() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25646,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743497', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743497();
# </script>
# <div id="root_plot_1771714743499" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743499() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25658,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743499', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743499();
# </script>
# <div id="root_plot_1771714743500" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743500() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25618,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743500', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743500();
# </script>
# <div id="root_plot_1771714743501" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743501() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25632,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743501', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743501();
# </script>
# <div id="root_plot_1771714743502" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743502() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25645,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743502', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743502();
# </script>
# <div id="root_plot_1771714743503" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714743503() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25658,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714743503', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714743503();
# </script>

# %%
more_canvs.append(draw_overlaid_stacks("no_pol_3ab_TGC_mc_cc10_vs_cc20", "no_pol_3ab_TGC_mc_cc10_vs_cc20", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.19, 0.15, 0.61, 0.30)))
more_canvs.append(draw_overlaid_stacks("no_pol_3ab_TGC_reco_cc10_vs_cc20", "no_pol_3ab_TGC_reco_cc10_vs_cc20", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.43, 0.85, 1., 1.)))
# Out:
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_mc_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_mc_cc10_vs_cc20_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_reco_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_TGC_reco_cc10_vs_cc20_overlaid_stacks.pdf has been created
# <div id="root_plot_1771714744268" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714744268() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(39367,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714744268', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714744268();
# </script>
# <div id="root_plot_1771714744273" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714744273() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(39365,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714744273', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714744273();
# </script>

# %%
more_canvs.append(draw_overlaid_stacks("new_share_high_ppol_3ab_TGC_mc_cc10_vs_cc20", "new_share_high_ppol_3ab_TGC_mc_cc10_vs_cc20", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.19, 0.15, 0.61, 0.30)))
more_canvs.append(draw_overlaid_stacks("new_share_high_ppol_3ab_TGC_reco_cc10_vs_cc20", "new_share_high_ppol_3ab_TGC_reco_cc10_vs_cc20", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.19, 0.15, 0.61, 0.30)))
# Out:
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/new_share_high_ppol_3ab_TGC_mc_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/new_share_high_ppol_3ab_TGC_mc_cc10_vs_cc20_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/new_share_high_ppol_3ab_TGC_reco_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/new_share_high_ppol_3ab_TGC_reco_cc10_vs_cc20_overlaid_stacks.pdf has been created
# <div id="root_plot_1771714744609" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714744609() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(39397,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714744609', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714744609();
# </script>
# <div id="root_plot_1771714744615" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714744615() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(39405,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714744615', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714744615();
# </script>

# %%
for k in ["free_pol", "constrained_pol"]:
    fit_res = fit_results[k]
    p = plotters[k]
    p.draw_plots_oo_names_per_run_name("no_pol_3ab_pol_mc_cc10_vs_cc20", "no_pol_3ab", fit_res, oo_names=[
        "av_nurec_nomb_mc",
        "av_nurec_nomb_mc_cc10",
    ], parameter_names=[
        "e_pol_0",
        "p_pol_0",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27), x_label_dict=x_axis_label_dict)
    # reco
    p.draw_plots_oo_names_per_run_name("no_pol_3ab_pol_reco_cc10_vs_cc20", "no_pol_3ab", fit_res, oo_names=[
        "mlvec_clean_brems_reco",
        "mlvec_clean_brems_reco_cc10",
    ], parameter_names=[
        "e_pol_0",
        "p_pol_0",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27), x_label_dict=x_axis_label_dict)
    # polarised
    p.draw_plots_oo_names_per_run_name("new_share_high_ppol_3ab_pol_mc_cc10_vs_cc20", "new_share_high_ppol_3ab", fit_res, oo_names=[
        "av_nurec_nomb_mc",
        "av_nurec_nomb_mc_cc10",
    ], parameter_names=[
        "e_pol_L",
        "e_pol_R",
        "p_pol_L",
        "p_pol_R",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27), x_label_dict=x_axis_label_dict)
    # reco
    p.draw_plots_oo_names_per_run_name("new_share_high_ppol_3ab_pol_reco_cc10_vs_cc20", "new_share_high_ppol_3ab", fit_res, oo_names=[
        "mlvec_clean_brems_reco",
        "mlvec_clean_brems_reco_cc10",
    ], parameter_names=[
        "e_pol_L",
        "e_pol_R",
        "p_pol_L",
        "p_pol_R",
    ], legend_name_dict=local_dict2, legend_pars=(0.16, 0.11, 0.58, 0.27), x_label_dict=x_axis_label_dict)
# Out:
# <div id="root_plot_1771714744745" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714744745() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25355,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714744745', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714744745();
# </script>
# <div id="root_plot_1771714744750" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714744750() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25366,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714744750', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714744750();
# </script>
# <div id="root_plot_1771714744755" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714744755() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(26200,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714744755', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714744755();
# </script>
# <div id="root_plot_1771714744758" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714744758() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(26210,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714744758', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714744758();
# </script>
# <div id="root_plot_1771714744761" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714744761() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25386,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714744761', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714744761();
# </script>
# <div id="root_plot_1771714744764" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714744764() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(25398,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714744764', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714744764();
# </script>
# <div id="root_plot_1771714744767" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714744767() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(26207,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714744767', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714744767();
# </script>
# <div id="root_plot_1771714744768" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714744768() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(26218,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714744768', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714744768();
# </script>

# %%
more_canvs.append(draw_overlaid_stacks("no_pol_3ab_pol_mc_cc10_vs_cc20", "no_pol_3ab_pol_mc_cc10_vs_cc20", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.19, 0.22, 0.61, 0.36)))
more_canvs.append(draw_overlaid_stacks("no_pol_3ab_pol_reco_cc10_vs_cc20", "no_pol_3ab_pol_reco_cc10_vs_cc20", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.19, 0.22, 0.61, 0.36)))
more_canvs.append(draw_overlaid_stacks("new_share_high_ppol_3ab_pol_mc_cc10_vs_cc20", "new_share_high_ppol_3ab_pol_mc_cc10_vs_cc20", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.38, 0.72, 0.80, 0.87)))
more_canvs.append(draw_overlaid_stacks("new_share_high_ppol_3ab_pol_reco_cc10_vs_cc20", "new_share_high_ppol_3ab_pol_reco_cc10_vs_cc20", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.38, 0.72, 0.80, 0.87)))
# Out:
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_pol_mc_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_pol_mc_cc10_vs_cc20_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_pol_reco_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/no_pol_3ab_pol_reco_cc10_vs_cc20_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/new_share_high_ppol_3ab_pol_mc_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/new_share_high_ppol_3ab_pol_mc_cc10_vs_cc20_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/new_share_high_ppol_3ab_pol_reco_cc10_vs_cc20_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/new_share_high_ppol_3ab_pol_reco_cc10_vs_cc20_overlaid_stacks.pdf has been created
# <div id="root_plot_1771714745215" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745215() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(32005,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745215', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745215();
# </script>
# <div id="root_plot_1771714745218" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745218() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(32015,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745218', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745218();
# </script>
# <div id="root_plot_1771714745219" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745219() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(33640,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745219', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745219();
# </script>
# <div id="root_plot_1771714745221" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745221() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(33652,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745221', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745221();
# </script>

# %%
for k in ["free_pol", "constrained_pol", "fixed_pol"]:
    fit_res = fit_results[k]
    p = plotters[k]
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_TGC", "mlvec_clean_brems_reco", fit_res, parameter_names=["g1z", "ka", "la", ], legend_pars=(0.7,0.55,1.,1.), legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_mW", "mlvec_clean_brems_reco", fit_res, parameter_names=["mW", ], legend_pars=(0.7, 0., 1., 0.45),
                                  legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_epols", "mlvec_clean_brems_reco", fit_res, parameter_names=["e_pol_L", "e_pol_R", "e_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_ppols", "mlvec_clean_brems_reco", fit_res, parameter_names=["p_pol_L", "p_pol_R", "p_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
# Out:
# <div id="root_plot_1771714745344" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745344() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28400,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745344', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745344();
# </script>
# <div id="root_plot_1771714745353" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745353() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27466,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745353', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745353();
# </script>
# <div id="root_plot_1771714745358" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745358() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28258,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745358', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745358();
# </script>
# <div id="root_plot_1771714745361" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745361() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28253,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745361', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745361();
# </script>
# <div id="root_plot_1771714745363" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745363() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28397,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745363', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745363();
# </script>
# <div id="root_plot_1771714745366" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745366() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27466,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745366', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745366();
# </script>
# <div id="root_plot_1771714745368" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745368() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28265,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745368', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745368();
# </script>
# <div id="root_plot_1771714745371" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745371() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28267,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745371', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745371();
# </script>
# <div id="root_plot_1771714745373" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745373() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28390,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745373', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745373();
# </script>
# <div id="root_plot_1771714745376" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745376() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27468,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745376', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745376();
# </script>
# <div id="root_plot_1771714745379" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745379() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27912,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745379', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745379();
# </script>
# <div id="root_plot_1771714745381" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714745381() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27912,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714745381', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714745381();
# </script>

# %%
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_TGC", "mlvec_clean_brems_reco_small_comp_TGC", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, y_max=2.3e-3, legend_columns=2, legend_pos=(0.16, 0.71, 0.94, 0.91), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_mW", "mlvec_clean_brems_reco_small_comp_mW", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_columns=2, legend_pos=(0.16, 0.15, 0.94, 0.40), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_epols", "mlvec_clean_brems_reco_small_comp_epols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.46, 0.38, 0.93, 0.89), y_max=1.8e-2, extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_ppols", "mlvec_clean_brems_reco_small_comp_ppols", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, y_max=1.8e-2, extra_legend_texts=extra_legend_text))
# Out:
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_TGC_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_TGC_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_mW_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_mW_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_epols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_epols_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_ppols_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_ppols_overlaid_stacks.pdf has been created
# <div id="root_plot_1771714746010" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746010() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(47848,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746010', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746010();
# </script>
# <div id="root_plot_1771714746018" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746018() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(45082,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746018', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746018();
# </script>
# <div id="root_plot_1771714746023" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746023() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(37980,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746023', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746023();
# </script>
# <div id="root_plot_1771714746027" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746027() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(37974,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746027', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746027();
# </script>

# %%
for k in ["free_pol", "constrained_pol", "fixed_pol"]:
    fit_res = fit_results[k]
    p = plotters[k]
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_TGC_cc10", "mlvec_clean_brems_reco_cc10", fit_res, parameter_names=["g1z", "ka", "la", ], legend_pars=(0.7,0.55,1.,1.), legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_mW_cc10", "mlvec_clean_brems_reco_cc10", fit_res, parameter_names=["mW", ], legend_pars=(0.7, 0., 1., 0.45),
                                  legend_name_dict=legend_name_dict_oo,
                                  run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                  ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_epols_cc10", "mlvec_clean_brems_reco_cc10", fit_res, parameter_names=["e_pol_L", "e_pol_R", "e_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
    p.draw_plots_runs_per_oo_name("mlvec_clean_brems_reco_small_comp_ppols_cc10", "mlvec_clean_brems_reco_cc10", fit_res, parameter_names=["p_pol_L", "p_pol_R", "p_pol_0"], legend_pars=(0.33,0.52,0.59,1.),
                                        legend_name_dict=legend_name_dict_oo,
                                        run_names=[
                                      "new_share_low_ppol_2ab",
                                      "new_share_low_ppol_3ab",
                                      "no_pol_10.8ab",
                                        ], no_draw=True, x_label_dict=x_axis_label_dict)
# Out:
# <div id="root_plot_1771714746149" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746149() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28382,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746149', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746149();
# </script>
# <div id="root_plot_1771714746157" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746157() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27451,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746157', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746157();
# </script>
# <div id="root_plot_1771714746161" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746161() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28220,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746161', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746161();
# </script>
# <div id="root_plot_1771714746164" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746164() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28222,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746164', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746164();
# </script>
# <div id="root_plot_1771714746167" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746167() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28384,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746167', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746167();
# </script>
# <div id="root_plot_1771714746169" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746169() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27453,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746169', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746169();
# </script>
# <div id="root_plot_1771714746171" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746171() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28250,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746171', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746171();
# </script>
# <div id="root_plot_1771714746174" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746174() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28253,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746174', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746174();
# </script>
# <div id="root_plot_1771714746176" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746176() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(28382,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746176', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746176();
# </script>
# <div id="root_plot_1771714746179" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746179() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27450,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746179', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746179();
# </script>
# <div id="root_plot_1771714746181" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746181() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27897,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746181', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746181();
# </script>
# <div id="root_plot_1771714746184" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714746184() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(27897,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714746184', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714746184();
# </script>

# %%
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_TGC_cc10", "mlvec_clean_brems_reco_small_comp_TGC_cc10", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, y_max=6.5e-3, legend_columns=2, legend_pos=(0.16, 0.71, 0.94, 0.91), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_mW_cc10", "mlvec_clean_brems_reco_small_comp_mW_cc10", ["free_pol", "constrained_pol", "fixed_pol"], plotters, plot_dir=plot_dir, legend_columns=2, legend_pos=(0.16, 0.15, 0.94, 0.40), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_epols_cc10", "mlvec_clean_brems_reco_small_comp_epols_cc10", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, legend_pos=(0.46, 0.38, 0.93, 0.89), extra_legend_texts=extra_legend_text))
more_canvs.append(draw_overlaid_stacks("mlvec_clean_brems_reco_small_comp_ppols_cc10", "mlvec_clean_brems_reco_small_comp_ppols_cc10", ["free_pol", "constrained_pol"], plotters, plot_dir=plot_dir, extra_legend_texts=extra_legend_text))
# Out:
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_TGC_cc10_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_TGC_cc10_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_mW_cc10_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_mW_cc10_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_epols_cc10_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_epols_cc10_overlaid_stacks.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_ppols_cc10_overlaid_stacks_no_legend.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/fit_results_bars/mlvec_clean_brems_reco_small_comp_ppols_cc10_overlaid_stacks.pdf has been created
# <div id="root_plot_1771714747175" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714747175() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(47830,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714747175', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714747175();
# </script>
# <div id="root_plot_1771714747181" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714747181() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(45071,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714747181', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714747181();
# </script>
# <div id="root_plot_1771714747187" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714747187() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(37979,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714747187', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714747187();
# </script>
# <div id="root_plot_1771714747190" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771714747190() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(37982,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771714747190', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771714747190();
# </script>
