# %%
import ROOT
from fitHelper import make_corr_mat
from pathlib import Path
# Out:
# OBJ: TStyle	ildStyle	ILD Style : 0 at: 0x2b5b2c0
# OBJ: TStyle	ildStyle	ILD Style : 0 at: 0x8098c30

# %%
# config_name = "ILC"
# config_name = "LCF"
config_name = "FCC"


plot_dir = f"plots/combined-fit/{config_name}"

# %%
Path(plot_dir).mkdir(parents=True, exist_ok=True)

# %%
n_runs_lc = 4
n_runs_cc = 1
par_names_lc = ["g1z", "ka", "la", "mW", "e_pol_L", "e_pol_R", "p_pol_L", "p_pol_R"]
par_names_cc = ["g1z", "ka", "la", "mW", "e_pol_0", "p_pol_0"]

# %%
configs = {
    "ILC": {
        "ws1_path": "workspaces/pol_constrained_2.5em3/mlvec_clean_brems_reco_new_share_low_ppol_2ab.root",
        "ws2_path": "workspaces/pol_constrained_2.5em3/mlvec_clean_brems_reco_cc10_new_share_low_ppol_2ab.root",
        "par_names": par_names_lc,
        "n_runs": n_runs_lc,
    },
    "LCF": {
        "ws1_path": "workspaces/pol_constrained_2.5em3/mlvec_clean_brems_reco_new_share_low_ppol_3ab.root",
        "ws2_path": "workspaces/pol_constrained_2.5em3/mlvec_clean_brems_reco_cc10_new_share_low_ppol_3ab.root",
        "par_names": par_names_lc,
        "n_runs": n_runs_lc,
    },
    "FCC": {
        "ws1_path": "workspaces/pol_constrained_2.5em3/mlvec_clean_brems_reco_no_pol_10.8ab.root",
        "ws2_path": "workspaces/pol_constrained_2.5em3/mlvec_clean_brems_reco_cc10_no_pol_10.8ab.root",
        "par_names": par_names_cc,
        "n_runs": n_runs_cc,
    },
}

# %%
config = configs[config_name]
ws1_path = config["ws1_path"]
ws2_path = config["ws2_path"]
par_names = config["par_names"]
n_runs = config["n_runs"]
# ws1_path = "workspaces/pol_constrained_2.5em3/av_nurec_nomb_mc_new_share_low_ppol_2ab.root"
# ws2_path = "workspaces/pol_constrained_2.5em3/av_nurec_nomb_mc_cc10_new_share_low_ppol_2ab.root"
ws1_path = "workspaces/pol_constrained_2.5em3/av_nurec_nomb_mc_no_pol_2ab.root"
ws2_path = "workspaces/pol_constrained_2.5em3/av_nurec_nomb_mc_cc10_no_pol_2ab.root"

# %%
w = ROOT.RooWorkspace("w")

# %%
w.Import(f"{ws1_path}:w:sim_model", RenameAllNodes="ws1")
w.Import(f"{ws2_path}:w:sim_model", RenameAllNodes="ws2")
# Out:
# False
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  sim_model to sim_model_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  fit_model_run0_with_constraints to fit_model_run0_with_constraints_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  fit_model_run0 to fit_model_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  mu_exp_0_run0 to mu_exp_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  rel_change_0_run0 to rel_change_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_0_0_run0 to var_0_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_0_1_run0 to var_0_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_0_2_run0 to var_0_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_0_3_run0 to var_0_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_0_4_run0 to var_0_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_0_5_run0 to var_0_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  mu_exp_1_run0 to mu_exp_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  rel_change_1_run0 to rel_change_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_1_0_run0 to var_1_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_1_1_run0 to var_1_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_1_2_run0 to var_1_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_1_3_run0 to var_1_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_1_4_run0 to var_1_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_1_5_run0 to var_1_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  mu_exp_2_run0 to mu_exp_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  rel_change_2_run0 to rel_change_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_2_0_run0 to var_2_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_2_1_run0 to var_2_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_2_2_run0 to var_2_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_2_3_run0 to var_2_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_2_4_run0 to var_2_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_2_5_run0 to var_2_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  mu_exp_3_run0 to mu_exp_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  rel_change_3_run0 to rel_change_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_3_0_run0 to var_3_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_3_1_run0 to var_3_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_3_2_run0 to var_3_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_3_3_run0 to var_3_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_3_4_run0 to var_3_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_3_5_run0 to var_3_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  mu_exp_4_run0 to mu_exp_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  rel_change_4_run0 to rel_change_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_4_0_run0 to var_4_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_4_1_run0 to var_4_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_4_2_run0 to var_4_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_4_3_run0 to var_4_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_4_4_run0 to var_4_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_4_5_run0 to var_4_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  mu_exp_5_run0 to mu_exp_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  rel_change_5_run0 to rel_change_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_5_0_run0 to var_5_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_5_1_run0 to var_5_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_5_2_run0 to var_5_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_5_3_run0 to var_5_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_5_4_run0 to var_5_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_5_5_run0 to var_5_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  constraint_e_pol_run0 to constraint_e_pol_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  constraint_p_pol_run0 to constraint_p_pol_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooSimultaneous::sim_model_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooCategory::runs
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProdPdf::fit_model_run0_with_constraints_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooMultiVarGaussian::fit_model_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::O_g1z
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::O_ka
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::O_la
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::O_mW
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::O_epol
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::O_ppol
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::mu_exp_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::rel_change_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_0_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::g1z
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-6.84175
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_0_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::ka
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-1.43023
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_0_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::la
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::4.41219
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_0_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::mW
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.142432
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_0_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::e_pol_0
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.0373511
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_0_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooRealVar::p_pol_0
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0396634
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.105964
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::mu_exp_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::rel_change_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_1_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-3.51241
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_1_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-7.7991
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_1_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::2.16257
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_1_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.220859
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_1_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0419285
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_1_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.0437833
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.0345647
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::mu_exp_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::rel_change_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_2_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-5.64414
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_2_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.927695
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_2_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::11.097
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_2_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0631928
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_2_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.025357
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_2_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.0162269
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0831556
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::mu_exp_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::rel_change_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_3_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.148614
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_3_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0532137
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_3_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0181535
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_3_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::7.86207
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_3_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.0495336
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_3_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.050399
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0885489
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::mu_exp_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::rel_change_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_4_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.13166
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_4_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0753744
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_4_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.169337
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_4_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0110274
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_4_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.0447202
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_4_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0449972
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.476617
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::mu_exp_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::rel_change_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_5_0_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.00717759
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_5_1_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.00225742
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_5_2_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.00313528
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_5_3_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.00488661
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_5_4_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.0180374
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_5_5_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.00185831
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.95488
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooGaussian::constraint_e_pol_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0025
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooGaussian::constraint_p_pol_run0_ws1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  sim_model to sim_model_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  fit_model_run0_with_constraints to fit_model_run0_with_constraints_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  fit_model_run0 to fit_model_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  mu_exp_0_run0 to mu_exp_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  rel_change_0_run0 to rel_change_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_0_0_run0 to var_0_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_0_1_run0 to var_0_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_0_2_run0 to var_0_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_0_3_run0 to var_0_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_0_4_run0 to var_0_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_0_5_run0 to var_0_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  mu_exp_1_run0 to mu_exp_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  rel_change_1_run0 to rel_change_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_1_0_run0 to var_1_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_1_1_run0 to var_1_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_1_2_run0 to var_1_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_1_3_run0 to var_1_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_1_4_run0 to var_1_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_1_5_run0 to var_1_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  mu_exp_2_run0 to mu_exp_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  rel_change_2_run0 to rel_change_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_2_0_run0 to var_2_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_2_1_run0 to var_2_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_2_2_run0 to var_2_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_2_3_run0 to var_2_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_2_4_run0 to var_2_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_2_5_run0 to var_2_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  mu_exp_3_run0 to mu_exp_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  rel_change_3_run0 to rel_change_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_3_0_run0 to var_3_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_3_1_run0 to var_3_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_3_2_run0 to var_3_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_3_3_run0 to var_3_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_3_4_run0 to var_3_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_3_5_run0 to var_3_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  mu_exp_4_run0 to mu_exp_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  rel_change_4_run0 to rel_change_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_4_0_run0 to var_4_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_4_1_run0 to var_4_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_4_2_run0 to var_4_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_4_3_run0 to var_4_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_4_4_run0 to var_4_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_4_5_run0 to var_4_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  mu_exp_5_run0 to mu_exp_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  rel_change_5_run0 to rel_change_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_5_0_run0 to var_5_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_5_1_run0 to var_5_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_5_2_run0 to var_5_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_5_3_run0 to var_5_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_5_4_run0 to var_5_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  var_5_5_run0 to var_5_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  constraint_e_pol_run0 to constraint_e_pol_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) Resolving name conflict in workspace by changing name of imported node  constraint_p_pol_run0 to constraint_p_pol_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooSimultaneous::sim_model_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProdPdf::fit_model_run0_with_constraints_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooMultiVarGaussian::fit_model_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::mu_exp_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::rel_change_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_0_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-4.35859
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_0_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.616875
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_0_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::2.87594
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_0_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.103102
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_0_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0596803
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_0_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.0576378
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.170907
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::mu_exp_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::rel_change_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_1_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.949459
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_1_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-1.23857
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_1_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.679537
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_1_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.0696373
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_1_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.15387
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_1_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.153439
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.143247
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::mu_exp_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::rel_change_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_2_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-3.72422
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_2_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.336402
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_2_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::6.85464
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_2_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.0880243
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_2_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.111608
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_2_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.107706
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.131199
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::mu_exp_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::rel_change_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_3_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.048995
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_3_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.112063
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_3_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0687682
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_3_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::5.62045
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_3_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.0153808
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_3_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0158745
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.123647
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::mu_exp_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::rel_change_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_4_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.128658
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_4_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0698604
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_4_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.157721
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_4_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0121797
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_4_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.0491108
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_4_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0490339
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.472173
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::mu_exp_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::rel_change_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_5_0_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.00852488
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_5_1_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0196134
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_5_2_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::1.79342e-05
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_5_3_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.000694196
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_5_4_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.00298852
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooProduct::var_5_5_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::0.0029954
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooConstVar::-0.985532
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooGaussian::constraint_e_pol_run0_ws2
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooGaussian::constraint_p_pol_run0_ws2

# %%
w.Print()
# Out:
# RooWorkspace(w) w contents
#
# variables
# ---------
# (O_epol,O_g1z,O_ka,O_la,O_mW,O_ppol,e_pol_0,g1z,ka,la,mW,p_pol_0,runs)
#
# p.d.f.s
# -------
# RooGaussian::constraint_e_pol_run0_ws1[ x=e_pol_0 mean=0 sigma=0.0025 ] = 1
# RooGaussian::constraint_e_pol_run0_ws2[ x=e_pol_0 mean=0 sigma=0.0025 ] = 1
# RooGaussian::constraint_p_pol_run0_ws1[ x=p_pol_0 mean=0 sigma=0.0025 ] = 1
# RooGaussian::constraint_p_pol_run0_ws2[ x=p_pol_0 mean=0 sigma=0.0025 ] = 1
# RooProdPdf::fit_model_run0_with_constraints_ws1[ fit_model_run0_ws1 * constraint_e_pol_run0_ws1 * constraint_p_pol_run0_ws1 ] = 1
# RooProdPdf::fit_model_run0_with_constraints_ws2[ fit_model_run0_ws2 * constraint_e_pol_run0_ws2 * constraint_p_pol_run0_ws2 ] = 0
# RooMultiVarGaussian::fit_model_run0_ws1[ x=(O_g1z,O_ka,O_la,O_mW,O_epol,O_ppol) mu=(mu_exp_0_run0_ws1,mu_exp_1_run0_ws1,mu_exp_2_run0_ws1,mu_exp_3_run0_ws1,mu_exp_4_run0_ws1,mu_exp_5_run0_ws1) ] = 1
# RooMultiVarGaussian::fit_model_run0_ws2[ x=(O_g1z,O_ka,O_la,O_mW,O_epol,O_ppol) mu=(mu_exp_0_run0_ws2,mu_exp_1_run0_ws2,mu_exp_2_run0_ws2,mu_exp_3_run0_ws2,mu_exp_4_run0_ws2,mu_exp_5_run0_ws2) ] = 0
# RooSimultaneous::sim_model_ws1[ indexCat=runs run_0=fit_model_run0_with_constraints_ws1 ] = 1
# RooSimultaneous::sim_model_ws2[ indexCat=runs run_0=fit_model_run0_with_constraints_ws2 ] = 0
#
# functions
# --------
# RooProduct::mu_exp_0_run0_ws1[ rel_change_0_run0_ws1 * -0.105964 ] = -0.105964
# RooProduct::mu_exp_0_run0_ws2[ rel_change_0_run0_ws2 * -0.170907 ] = -0.170907
# RooProduct::mu_exp_1_run0_ws1[ rel_change_1_run0_ws1 * -0.0345647 ] = -0.0345647
# RooProduct::mu_exp_1_run0_ws2[ rel_change_1_run0_ws2 * -0.143247 ] = -0.143247
# RooProduct::mu_exp_2_run0_ws1[ rel_change_2_run0_ws1 * 0.0831556 ] = 0.0831556
# RooProduct::mu_exp_2_run0_ws2[ rel_change_2_run0_ws2 * 0.131199 ] = 0.131199
# RooProduct::mu_exp_3_run0_ws1[ rel_change_3_run0_ws1 * 0.0885489 ] = 0.0885489
# RooProduct::mu_exp_3_run0_ws2[ rel_change_3_run0_ws2 * 0.123647 ] = 0.123647
# RooProduct::mu_exp_4_run0_ws1[ rel_change_4_run0_ws1 * -0.476617 ] = -0.476617
# RooProduct::mu_exp_4_run0_ws2[ rel_change_4_run0_ws2 * -0.472173 ] = -0.472173
# RooProduct::mu_exp_5_run0_ws1[ rel_change_5_run0_ws1 * -0.95488 ] = -0.95488
# RooProduct::mu_exp_5_run0_ws2[ rel_change_5_run0_ws2 * -0.985532 ] = -0.985532
# RooAddition::rel_change_0_run0_ws1[ 1 + var_0_0_run0_ws1 + var_0_1_run0_ws1 + var_0_2_run0_ws1 + var_0_3_run0_ws1 + var_0_4_run0_ws1 + var_0_5_run0_ws1 ] = 1
# RooAddition::rel_change_0_run0_ws2[ 1 + var_0_0_run0_ws2 + var_0_1_run0_ws2 + var_0_2_run0_ws2 + var_0_3_run0_ws2 + var_0_4_run0_ws2 + var_0_5_run0_ws2 ] = 1
# RooAddition::rel_change_1_run0_ws1[ 1 + var_1_0_run0_ws1 + var_1_1_run0_ws1 + var_1_2_run0_ws1 + var_1_3_run0_ws1 + var_1_4_run0_ws1 + var_1_5_run0_ws1 ] = 1
# RooAddition::rel_change_1_run0_ws2[ 1 + var_1_0_run0_ws2 + var_1_1_run0_ws2 + var_1_2_run0_ws2 + var_1_3_run0_ws2 + var_1_4_run0_ws2 + var_1_5_run0_ws2 ] = 1
# RooAddition::rel_change_2_run0_ws1[ 1 + var_2_0_run0_ws1 + var_2_1_run0_ws1 + var_2_2_run0_ws1 + var_2_3_run0_ws1 + var_2_4_run0_ws1 + var_2_5_run0_ws1 ] = 1
# RooAddition::rel_change_2_run0_ws2[ 1 + var_2_0_run0_ws2 + var_2_1_run0_ws2 + var_2_2_run0_ws2 + var_2_3_run0_ws2 + var_2_4_run0_ws2 + var_2_5_run0_ws2 ] = 1
# RooAddition::rel_change_3_run0_ws1[ 1 + var_3_0_run0_ws1 + var_3_1_run0_ws1 + var_3_2_run0_ws1 + var_3_3_run0_ws1 + var_3_4_run0_ws1 + var_3_5_run0_ws1 ] = 1
# RooAddition::rel_change_3_run0_ws2[ 1 + var_3_0_run0_ws2 + var_3_1_run0_ws2 + var_3_2_run0_ws2 + var_3_3_run0_ws2 + var_3_4_run0_ws2 + var_3_5_run0_ws2 ] = 1
# RooAddition::rel_change_4_run0_ws1[ 1 + var_4_0_run0_ws1 + var_4_1_run0_ws1 + var_4_2_run0_ws1 + var_4_3_run0_ws1 + var_4_4_run0_ws1 + var_4_5_run0_ws1 ] = 1
# RooAddition::rel_change_4_run0_ws2[ 1 + var_4_0_run0_ws2 + var_4_1_run0_ws2 + var_4_2_run0_ws2 + var_4_3_run0_ws2 + var_4_4_run0_ws2 + var_4_5_run0_ws2 ] = 1
# RooAddition::rel_change_5_run0_ws1[ 1 + var_5_0_run0_ws1 + var_5_1_run0_ws1 + var_5_2_run0_ws1 + var_5_3_run0_ws1 + var_5_4_run0_ws1 + var_5_5_run0_ws1 ] = 1
# RooAddition::rel_change_5_run0_ws2[ 1 + var_5_0_run0_ws2 + var_5_1_run0_ws2 + var_5_2_run0_ws2 + var_5_3_run0_ws2 + var_5_4_run0_ws2 + var_5_5_run0_ws2 ] = 1
# RooProduct::var_0_0_run0_ws1[ g1z * -6.84175 ] = 0
# RooProduct::var_0_0_run0_ws2[ g1z * -4.35859 ] = 0
# RooProduct::var_0_1_run0_ws1[ ka * -1.43023 ] = 0
# RooProduct::var_0_1_run0_ws2[ ka * -0.616875 ] = 0
# RooProduct::var_0_2_run0_ws1[ la * 4.41219 ] = 0
# RooProduct::var_0_2_run0_ws2[ la * 2.87594 ] = 0
# RooProduct::var_0_3_run0_ws1[ mW * -0.142432 ] = 0
# RooProduct::var_0_3_run0_ws2[ mW * -0.103102 ] = 0
# RooProduct::var_0_4_run0_ws1[ e_pol_0 * -0.0373511 ] = 0
# RooProduct::var_0_4_run0_ws2[ e_pol_0 * 0.0596803 ] = 0
# RooProduct::var_0_5_run0_ws1[ p_pol_0 * 0.0396634 ] = 0
# RooProduct::var_0_5_run0_ws2[ p_pol_0 * -0.0576378 ] = 0
# RooProduct::var_1_0_run0_ws1[ g1z * -3.51241 ] = 0
# RooProduct::var_1_0_run0_ws2[ g1z * -0.949459 ] = 0
# RooProduct::var_1_1_run0_ws1[ ka * -7.7991 ] = 0
# RooProduct::var_1_1_run0_ws2[ ka * -1.23857 ] = 0
# RooProduct::var_1_2_run0_ws1[ la * 2.16257 ] = 0
# RooProduct::var_1_2_run0_ws2[ la * 0.679537 ] = 0
# RooProduct::var_1_3_run0_ws1[ mW * -0.220859 ] = 0
# RooProduct::var_1_3_run0_ws2[ mW * -0.0696373 ] = 0
# RooProduct::var_1_4_run0_ws1[ e_pol_0 * 0.0419285 ] = 0
# RooProduct::var_1_4_run0_ws2[ e_pol_0 * 0.15387 ] = 0
# RooProduct::var_1_5_run0_ws1[ p_pol_0 * -0.0437833 ] = 0
# RooProduct::var_1_5_run0_ws2[ p_pol_0 * -0.153439 ] = 0
# RooProduct::var_2_0_run0_ws1[ g1z * -5.64414 ] = 0
# RooProduct::var_2_0_run0_ws2[ g1z * -3.72422 ] = 0
# RooProduct::var_2_1_run0_ws1[ ka * -0.927695 ] = 0
# RooProduct::var_2_1_run0_ws2[ ka * -0.336402 ] = 0
# RooProduct::var_2_2_run0_ws1[ la * 11.097 ] = 0
# RooProduct::var_2_2_run0_ws2[ la * 6.85464 ] = 0
# RooProduct::var_2_3_run0_ws1[ mW * 0.0631928 ] = 0
# RooProduct::var_2_3_run0_ws2[ mW * -0.0880243 ] = 0
# RooProduct::var_2_4_run0_ws1[ e_pol_0 * 0.025357 ] = 0
# RooProduct::var_2_4_run0_ws2[ e_pol_0 * 0.111608 ] = 0
# RooProduct::var_2_5_run0_ws1[ p_pol_0 * -0.0162269 ] = 0
# RooProduct::var_2_5_run0_ws2[ p_pol_0 * -0.107706 ] = 0
# RooProduct::var_3_0_run0_ws1[ g1z * 0.148614 ] = 0
# RooProduct::var_3_0_run0_ws2[ g1z * 0.048995 ] = 0
# RooProduct::var_3_1_run0_ws1[ ka * 0.0532137 ] = 0
# RooProduct::var_3_1_run0_ws2[ ka * 0.112063 ] = 0
# RooProduct::var_3_2_run0_ws1[ la * 0.0181535 ] = 0
# RooProduct::var_3_2_run0_ws2[ la * 0.0687682 ] = 0
# RooProduct::var_3_3_run0_ws1[ mW * 7.86207 ] = 0
# RooProduct::var_3_3_run0_ws2[ mW * 5.62045 ] = 0
# RooProduct::var_3_4_run0_ws1[ e_pol_0 * -0.0495336 ] = 0
# RooProduct::var_3_4_run0_ws2[ e_pol_0 * -0.0153808 ] = 0
# RooProduct::var_3_5_run0_ws1[ p_pol_0 * 0.050399 ] = 0
# RooProduct::var_3_5_run0_ws2[ p_pol_0 * 0.0158745 ] = 0
# RooProduct::var_4_0_run0_ws1[ g1z * -0.13166 ] = 0
# RooProduct::var_4_0_run0_ws2[ g1z * -0.128658 ] = 0
# RooProduct::var_4_1_run0_ws1[ ka * 0.0753744 ] = 0
# RooProduct::var_4_1_run0_ws2[ ka * 0.0698604 ] = 0
# RooProduct::var_4_2_run0_ws1[ la * 0.169337 ] = 0
# RooProduct::var_4_2_run0_ws2[ la * 0.157721 ] = 0
# RooProduct::var_4_3_run0_ws1[ mW * 0.0110274 ] = 0
# RooProduct::var_4_3_run0_ws2[ mW * 0.0121797 ] = 0
# RooProduct::var_4_4_run0_ws1[ e_pol_0 * -0.0447202 ] = 0
# RooProduct::var_4_4_run0_ws2[ e_pol_0 * -0.0491108 ] = 0
# RooProduct::var_4_5_run0_ws1[ p_pol_0 * 0.0449972 ] = 0
# RooProduct::var_4_5_run0_ws2[ p_pol_0 * 0.0490339 ] = 0
# RooProduct::var_5_0_run0_ws1[ g1z * -0.00717759 ] = 0
# RooProduct::var_5_0_run0_ws2[ g1z * -0.00852488 ] = 0
# RooProduct::var_5_1_run0_ws1[ ka * -0.00225742 ] = 0
# RooProduct::var_5_1_run0_ws2[ ka * 0.0196134 ] = 0
# RooProduct::var_5_2_run0_ws1[ la * -0.00313528 ] = 0
# RooProduct::var_5_2_run0_ws2[ la * 1.79342e-05 ] = 0
# RooProduct::var_5_3_run0_ws1[ mW * 0.00488661 ] = 0
# RooProduct::var_5_3_run0_ws2[ mW * 0.000694196 ] = 0
# RooProduct::var_5_4_run0_ws1[ e_pol_0 * -0.0180374 ] = 0
# RooProduct::var_5_4_run0_ws2[ e_pol_0 * -0.00298852 ] = 0
# RooProduct::var_5_5_run0_ws1[ p_pol_0 * 0.00185831 ] = 0
# RooProduct::var_5_5_run0_ws2[ p_pol_0 * 0.0029954 ] = 0

# %%
cat = ROOT.RooCategory("runs_ws", "Run configurations", {f"ws_{i}_run_{j}": n_runs*(i-1)+j for i in [1, 2] for j in range(n_runs)})
cat.Print("v")
# Out:
# --- RooAbsArg ---
#   Value State: clean
#   Shape State: clean
#   Attributes:
#   Address: 0xb721a10
#   Clients:
#   Servers:
#   Proxies:
# --- RooAbsCategory ---
#   Value = 0 "ws_1_run_0)
#   Possible states:
#     ws_1_run_0	0
#     ws_2_run_0	1

# %%
# pdf_map = {f"ws_{i}_run_{j}": w.pdf(f"fit_model_run{j}_with_constraints_ws{i}") for i in [1, 2] for j in range(n_runs)}
pdf_map = {f"ws_{i}_run_{j}": w.pdf(f"fit_model_run{j}_with_constraints_ws{i}") for i in [1] for j in range(n_runs)}
pdf_map |= {f"ws_{i}_run_{j}": w.pdf(f"fit_model_run{j}_ws{i}") for i in [2] for j in range(n_runs)}
print(pdf_map)
# Out:
# {'ws_1_run_0': <cppyy.gbl.RooProdPdf object at 0xb65cb50>, 'ws_2_run_0': <cppyy.gbl.RooMultiVarGaussian object at 0xb7b6060>}

# %%
sim_model = ROOT.RooSimultaneous("sim_model", "Simultaneous fit model", pdf_map, cat)
w.Import(sim_model)
# Out:
# False
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooSimultaneous::sim_model
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooCategory::runs_ws

# %%
obs_names = [f"O_{par}" for par in ["g1z", "ka", "la", "mW", "epol", "ppol"]]
obs = [w.var(name) for name in obs_names]
print(obs)
# Out:
# [<cppyy.gbl.RooRealVar object at 0xb664740>, <cppyy.gbl.RooRealVar object at 0xb664cc0>, <cppyy.gbl.RooRealVar object at 0xb6652c0>, <cppyy.gbl.RooRealVar object at 0xb665860>, <cppyy.gbl.RooRealVar object at 0xb665e00>, <cppyy.gbl.RooRealVar object at 0xb6663a0>]

# %%
ds = ROOT.RooStats.AsymptoticCalculator.GenerateAsimovData(sim_model, obs)
ds.printContents()
# Out:
# Contents of RooDataSet "asimovDataFullModel"
#   Entry 0: O_g1z=-0.105964, O_ka=-0.0345647, O_la=0.0831556, O_mW=0.0885489, O_epol=-0.476617, O_ppol=-0.95488, runs_ws=ws_1_run_0, weight=1
#   Entry 1: O_g1z=-0.170907, O_ka=-0.143247, O_la=0.131199, O_mW=0.123647, O_epol=-0.472173, O_ppol=-0.985532, runs_ws=ws_2_run_0, weight=1

# %%
# w.var("g1z").setConstant(True)
# w.var("ka").setConstant(True)
# w.var("la").setConstant(True)
w.var("mW").setConstant(True)
# w.var("e_pol_L").setConstant(True)
# w.var("e_pol_R").setConstant(True)
# w.var("p_pol_L").setConstant(True)
# w.var("p_pol_R").setConstant(True)

w.var("e_pol_0").setConstant(True)
w.var("p_pol_0").setConstant(True)

# %%
nll = sim_model.createNLL(ds)
# Out:
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (constraint_e_pol_run0_ws1,constraint_p_pol_run0_ws1)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (e_pol_0,g1z,ka,la,mW,p_pol_0)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(sim_model) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- using generic CPU library compiled with no vectorizations
# [#1] INFO:Fitting -- Creation of NLL object took 6.04915 ms

# %%
nll_minimizer = ROOT.RooMinimizer(nll)
# Out:
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_sim_model_asimovDataFullModel) Summation contains a RooNLLVar, using its error level

# %%
nll_minimizer.migrad()
# Out:
# 0
# [#1] INFO:Minimization -- [fitFCN] No discrete parameters, performing continuous minimization only
# Minuit2Minimizer: Minimize with max-calls 1500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = -98.6502054375780659
# Edm   = 0
# Nfcn  = 29
# g1z	  = 0	 +/-  0.000539329	(limited)
# ka	  = 0	 +/-  0.000769146	(limited)
# la	  = 0	 +/-  0.000473491	(limited)
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Evaluated function and gradient in 315.981 μs
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =      -98.65020544 Edm =                 0 NCalls =     13
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : -98.65020544
#   Edm           : 0
#   Internal parameters:	[                0                0                0]
#   Internal gradient  :	[                0                0                0]
#   Internal covariance matrix:
# [[  1.4035454e-06              0              0]
#  [              0  4.4824446e-06              0]
#  [              0              0  1.1259017e-06]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 1500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =      -98.65020544 Edm =                 0 NCalls =     13
# Info in <Minuit2>: MnHesse Done after 131.68 μs
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =      -98.65020544 Edm =                 0 NCalls =     29
# Info in <Minuit2>: VariableMetricBuilder Stop iterating after 162.108 μs

# %%
nll_minimizer.hesse()
# Out:
# 0
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 1500
# Info in <Minuit2>: MnHesse Done after 393.009 μs
# Info in <Minuit2>: Minuit2Minimizer::Hesse Hesse is valid - matrix is accurate

# %%
res = nll_minimizer.lastMinuitFit()
res.Print()
# Out:
#   RooFitResult: minimized FCN value: -98.6502, estimated distance to minimum: 0
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status :
#
#     Floating Parameter    FinalValue +/-  Error
#   --------------------  --------------------------
#                    g1z    0.0000e+00 +/-  5.39e-04
#                     ka    0.0000e+00 +/-  7.69e-04
#                     la    0.0000e+00 +/-  4.73e-04

# %%
final_pars = res.floatParsFinal()
text = ""
for par_name in par_names:
    par = final_pars.find(par_name)
    if not par:
        continue
    text += f"{par_name}: {par.getVal()} ± {par.getError():.2e}\n"
print(text)
# with open(f"{plot_dir}/fit_results.txt", "w") as f:
#     f.write(text)
# Out:
# g1z: 0.0 ± 5.39e-04
# ka: 0.0 ± 7.69e-04
# la: 0.0 ± 4.73e-04

# %%
name_dict = {
    "g1z": "g_{1}^{Z}",
    "ka": "#kappa_{#gamma}",
    "la": "#lambda_{#gamma}",
    "mW": "m_{W}",
    "e_pol_L": "P_{e^{-}}^{-}",
    "e_pol_R": "P_{e^{-}}^{+}",
    "e_pol_0": "P_{e^{-}}^{0}",
    "p_pol_L": "P_{e^{+}}^{-}",
    "p_pol_R": "P_{e^{+}}^{+}",
    "p_pol_0": "P_{e^{+}}^{0}",
}

# %%
h = make_corr_mat(res, par_names, w, name_dict)
ch = ROOT.TCanvas()
h.SetMinimum(-1)
h.SetMaximum(1)
h.SetTitle(config_name)
h.Draw("col text")
h.SetMarkerSize(1.8)
ch.SetLeftMargin(0.1)
ch.SetRightMargin(0.05)
ch.SetBottomMargin(0.1)
ch.Draw()
ch.SaveAs(f"{plot_dir}/correlation_matrix.pdf")
# Out:
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter p_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter e_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter mW is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter p_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter e_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter mW is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter p_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter e_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter mW is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter mW is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter mW is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter mW is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter mW is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter mW is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter mW is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter e_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter e_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter e_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter e_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter e_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter e_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter p_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter p_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter p_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter p_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter p_pol_0 is not a floating fit parameter
# [#0] ERROR:InputArguments -- RooFitResult::correlation(lastMinuitFit) parameter p_pol_0 is not a floating fit parameter
# Info in <TCanvas::Print>: pdf file plots/combined-fit/FCC/correlation_matrix.pdf has been created
# <div id="root_plot_1771316481216" style="width: 700px; height: 500px; position: relative">
# </div>
# <script>
#    function process_root_plot_1771316481216() {
#       function drawPlot(Core) {
#          Core.settings.HandleKeys = false;
#          Core.unzipJSON(21245,'...').then(json => {
#             const obj = Core.parse(json);
#             Core.draw('root_plot_1771316481216', obj, '');
#          });
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          drawPlot(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1771316481216();
# </script>
