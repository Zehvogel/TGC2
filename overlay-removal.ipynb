# %%
import ROOT
# Out:
# OBJ: TStyle	ildStyle	ILD Style : 0 at: 0x8dc2a70

# %%
ROOT.EnableImplicitMT(12)

# %%
ROOT.gInterpreter.Declare("#include \"analyzers.h\"")
# Out:
# True

# %%
files = {
    "4f_ww_l": [],
    "4f_sw_sl": [],
    "4f_ww_h": [],
}

with open("data/locations/miniDSTs/processed-no-exc-higgs.txt", "r") as loc_file:
    for line in loc_file:
        for k in files:
            if k in line:
                files[k].append(line.strip())

# %%
df = {}
for k in files:
    df[k] = ROOT.RDataFrame("events", files[k])
# Out:
# OBJ: TStyle	ildStyle	ILD Style : 0 at: 0xd2ead20
# Warning in <TClass::Init>: no dictionary for class edm4hep::Vector2i is available

# %%
ROOT.gStyle.SetPalette(ROOT.kBird)

# %%
for k, f in df.items():
    f = f.Define("p_vec_all", "Construct<ROOT::Math::XYZVector>(PandoraPFOs.momentum.x, PandoraPFOs.momentum.y, PandoraPFOs.momentum.z)")
    f = f.Define("non_iso_mask", "subset_to_mask(PandoraPFOs, PFOsminusphoton_objIdx)")
    f = f.Define("p_vec", "p_vec_all[non_iso_mask]")
    f = f.Define("p_theta", "return Map(p_vec, [] (const auto& el) {return el.Theta();})")
    f = f.Define("p_pt", "return Map(p_vec, [] (const auto& el) {return el.Rho();})")
    f = f.Define("p_sintheta", "sin(p_theta)")
    f = f.Define("p_logpt", "log10(p_pt)")
    df[k] = f

# %%
h = {}
count = {}
for k, f in df.items():
    h[k] = f.Histo2D(("", f"{k};sin#theta;log_{{10}} p_{{T}}", 100, 0., 1., 100, -1., 2.), "p_sintheta", "p_logpt")
    count[k] = f.Count()

# %%
c = {}
for k in h:
    c[k] = ROOT.TCanvas()
    h[k].Draw("colz")
    c[k].Draw()
# Out:
# <div id="root_plot_1758785493766" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1758785493766(Core) {
# ...

# %%
h_norm = {}
for k in h:
    h_t = h[k].Clone()
    h_t.Scale(1. / count[k].GetValue())
    h_norm[k] = h_t

# %%
h_sl_by_l = h_norm["4f_sw_sl"].Clone()
h_sl_by_l.Divide(h_norm["4f_ww_l"])

h_h_by_l = h_norm["4f_ww_h"].Clone()
h_h_by_l.Divide(h_norm["4f_ww_l"])
# Out:
# True

# %%
f = ROOT.TF1("f", "-2*x+0.2")

# %%
c_sl_by_l = ROOT.TCanvas()
h_sl_by_l.Draw("colz")
f.Draw("same")
c_sl_by_l.Draw()
c_sl_by_l.SetLogz()
h_sl_by_l.SetMinimum(0.1)
h_sl_by_l.SetMaximum(10.)

c_h_by_l = ROOT.TCanvas()
h_h_by_l.Draw("colz")
f.Draw("same")
c_h_by_l.Draw()
c_h_by_l.SetLogz()
h_h_by_l.SetMinimum(0.1)
h_h_by_l.SetMaximum(10.)
# Out:
# <div id="root_plot_1758785494391" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1758785494391(Core) {
# ...
